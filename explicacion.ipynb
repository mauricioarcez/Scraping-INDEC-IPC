# %%
import numpy as np
import requests
import pandas as pd
import io
import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# # Script para Descargar y Leer el Archivo Excel del IPC
#
# Este script se encarga de descargar un archivo Excel que contiene datos sobre el Índice de Precios al Consumidor (IPC) desde el sitio web del INDEC y lo carga en un DataFrame de pandas para su posterior análisis.
#
# - Se define la URL directa del archivo Excel que se desea descargar. Ya que todos los datos son cargados en esa url directa.
# - Se realiza una solicitud GET a la URL para obtener el archivo Excel.
# - Se obtiene una lista de las hojas disponibles en el archivo y se imprime.
# - Si la solicitud no es exitosa, se imprime un mensaje de error con el código de estado correspondiente.

# %%
# URL directa del ipc
url_excel = 'https://www.indec.gob.ar/ftp/cuadros/economia/sh_ipc_precios_promedio.xls'

# Obtener el archivo Excel
response = requests.get(url_excel)

# Verificar la solicitud
if response.status_code == 200:
    # Leer el contenido del archivo Excel en un DataFrame
    indec_ipc = pd.read_excel(io.BytesIO(response.content), sheet_name=None, engine='xlrd')
    paginador = list(indec_ipc.keys())
    print(paginador)
else:
    print(f"Error al descargar el archivo: {response.status_code}")
# Out:
# ['Nacional', 'GBA']

# %%
nacional = indec_ipc[paginador[0]] # Leer solamente la hoja Nacional.
comienzo = nacional.iloc[:10] # Ver el comienzo del dataset.
comienzo
# Out:
#   Precios al consumidor de una selección de alimentos, bebidas y otros artículos de la canasta del Índice de precios al consumidor, según regiones. Junio 2017- noviembre 2024  \
# 0                                                NaN
# 1                                             Región
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                GBA
# 6                                                GBA
# 7                                                GBA
# 8                                                GBA
# 9                                                GBA
#
#                   Unnamed: 1        Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        NaN               NaN        NaN        NaN
# 1    Productos seleccionados  Unidad de medida   Año 2017        NaN
# 2                        NaN               NaN      Junio      Julio
# 3                        NaN               NaN      Pesos        NaN
# 4                        NaN               NaN        NaN        NaN
# 5                Pan francés                kg      38.64      39.12
# 6      Harina de trigo común                kg      10.67      10.61
# 7        Arroz blanco simple                kg      20.96      21.08
# 8  Fideos secos tipo guisero             500 g      19.08      19.53
# 9         Carne picada común                kg       72.2      72.71
#
#   Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# 0        NaN         NaN        NaN        NaN        NaN          NaN
# 1        NaN         NaN        NaN        NaN        NaN          NaN
# 2     Agosto  Septiembre    Octubre  Noviembre  Diciembre          NaN
# 3        NaN         NaN        NaN        NaN        NaN          NaN
# 4        NaN         NaN        NaN        NaN        NaN          NaN
# 5      39.43       39.71      39.89      40.24      40.55          NaN
# 6      10.65       10.66      10.61      10.81      11.03          NaN
# 7      21.25       21.49      21.74      21.74       22.1          NaN
# 8      19.73       19.86      20.13      20.34      20.54          NaN
# 9       73.4       73.28      73.75      73.83      72.92          NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1    Año 2018         NaN         NaN         NaN         NaN         NaN
# 2       Enero     Febrero       Marzo       Abril        Mayo       Junio
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5       41.29       42.62       44.38       45.83       49.81       55.19
# 6        11.2       11.64       11.94       12.72       16.69       20.99
# 7       22.81       23.22       23.84       24.37       24.64       25.99
# 8       21.23       21.56       22.35       22.86       25.03       26.94
# 9       72.19       75.63       77.08        80.3        83.4       90.41
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2       Julio      Agosto  Septiembre     Octubre   Noviembre   Diciembre
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5       57.05       57.61       67.25        71.9       72.63       73.49
# 6       23.35       24.09       26.92       29.19       30.23       30.32
# 7       26.82        28.7       33.39       35.53       37.65       38.61
# 8       28.33       28.88       34.68       37.81       40.34       41.28
# 9       91.52       95.14      102.45      105.97      106.89      106.47
#
#    Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN    Año 2019         NaN         NaN         NaN         NaN
# 2          NaN       Enero     Febrero       Marzo       Abril        Mayo
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN       75.04       76.94        79.9       81.56       83.89
# 6          NaN       30.81       31.28       31.56       31.69       33.15
# 7          NaN       39.39        40.6       40.94        42.2       44.27
# 8          NaN       42.15       43.21       43.89       46.99        48.3
# 9          NaN      113.53      126.42      134.04      135.35      137.67
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2       Junio       Julio      Agosto  Septiembre     Octubre   Noviembre
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5       87.52       88.68       92.16       98.61      100.62      106.12
# 6        34.3       34.85       36.04       38.34        38.9       39.48
# 7       45.36       45.83       48.48        49.5       50.38       54.75
# 8       48.47       49.29       49.95       51.45       52.06       53.09
# 9      137.31      141.22      147.85      156.25      157.13      168.39
#
#   Unnamed: 35  Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40  \
# 0         NaN          NaN         NaN         NaN         NaN         NaN
# 1         NaN          NaN    Año 2020         NaN         NaN         NaN
# 2   Diciembre          NaN      Enero      Febrero       Marzo       Abril
# 3         NaN          NaN         NaN         NaN         NaN         NaN
# 4         NaN          NaN         NaN         NaN         NaN         NaN
# 5      108.02          NaN      111.25      112.99      116.37      116.52
# 6       40.24          NaN       42.07       43.62       43.43        43.7
# 7       57.46          NaN       63.84       66.04       67.75       70.13
# 8       53.79          NaN       56.92       58.85       59.15       59.79
# 9      178.35          NaN      202.41      209.42      214.88      227.42
#
#   Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2        Mayo       Junio       Julio      Agosto  Septiembre     Octubre
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5      113.97      116.46      116.71      116.91      127.31       132.1
# 6       44.22       44.41       45.62       46.04       46.12       47.66
# 7       70.22       72.56       73.25        73.8       75.75       80.55
# 8        59.1       58.07       59.54       60.08       60.37       60.39
# 9      229.53      230.34      235.95      247.99      248.81      254.61
#
#   Unnamed: 47 Unnamed: 48  Unnamed: 49 Unnamed: 50 Unnamed: 51 Unnamed: 52  \
# 0         NaN         NaN          NaN         NaN         NaN         NaN
# 1         NaN         NaN          NaN    Año 2021         NaN         NaN
# 2   Noviembre   Diciembre          NaN       Enero     Febrero       Marzo
# 3         NaN         NaN          NaN         NaN         NaN         NaN
# 4         NaN         NaN          NaN         NaN         NaN         NaN
# 5      138.31      140.13          NaN      145.61      151.12      157.27
# 6       45.17       42.55          NaN       43.62       45.06       45.12
# 7        80.9       81.76          NaN       81.53       81.61       84.36
# 8       61.54       60.87          NaN       61.51       64.04       66.86
# 9      271.41       300.9          NaN      313.33      327.65      355.55
#
#   Unnamed: 53 Unnamed: 54 Unnamed: 55 Unnamed: 56 Unnamed: 57 Unnamed: 58  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2       Abril        Mayo       Junio       Julio      Agosto  Septiembre
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5  164.717943  172.293019  182.910621  185.115699  188.621431      190.09
# 6   46.399629   49.505956   50.938056   52.709116   53.547283       56.83
# 7   96.383823  108.970153  111.682709  111.743491  117.360672      115.14
# 8   68.865182   69.448831   71.159583   73.690747   75.188592       75.34
# 9  372.637742  407.231597  427.820657  429.771087  414.759301      431.41
#
#   Unnamed: 59 Unnamed: 60 Unnamed: 61  Unnamed: 62 Unnamed: 63 Unnamed: 64  \
# 0         NaN         NaN         NaN          NaN         NaN         NaN
# 1         NaN         NaN         NaN          NaN    Año 2022         NaN
# 2     Octubre   Noviembre   Diciembre          NaN       Enero     Febrero
# 3         NaN         NaN         NaN          NaN         NaN         NaN
# 4         NaN         NaN         NaN          NaN         NaN         NaN
# 5      197.99      204.32      207.97          NaN      209.92      225.82
# 6       59.29       59.37       59.46          NaN       62.82       65.55
# 7      116.74      114.43      114.82          NaN       120.6      120.62
# 8       77.52       76.95       78.44          NaN        80.6        84.2
# 9      430.85      479.86      507.32          NaN      481.74      538.25
#
#   Unnamed: 65 Unnamed: 66 Unnamed: 67 Unnamed: 68 Unnamed: 69 Unnamed: 70  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2       Marzo       Abril        Mayo       Junio       Julio      Agosto
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5      265.71      295.24      301.62       311.8      327.39       343.1
# 6       74.22       86.18       95.25       95.24      107.06      114.41
# 7       124.5      127.08      131.18      136.95      137.75      143.83
# 8       93.18      100.91      108.12      122.06      139.54      152.35
# 9      559.84      614.62      664.87      686.83      695.04      697.06
#
#   Unnamed: 71 Unnamed: 72 Unnamed: 73 Unnamed: 74  Unnamed: 75 Unnamed: 76  \
# 0         NaN         NaN         NaN         NaN          NaN         NaN
# 1         NaN         NaN         NaN         NaN          NaN    Año 2023
# 2  Septiembre     Octubre   Noviembre   Diciembre          NaN       Enero
# 3         NaN         NaN         NaN         NaN          NaN         NaN
# 4         NaN         NaN         NaN         NaN          NaN         NaN
# 5      366.54       385.2      407.77      428.42          NaN      435.66
# 6      123.46      132.37       140.7      146.91          NaN      160.14
# 7      154.33      167.76      173.27      183.52          NaN      198.02
# 8      162.58      177.09      184.35      191.91          NaN      207.95
# 9      719.47      728.26      704.96      698.77          NaN      750.61
#
#   Unnamed: 77 Unnamed: 78 Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2     Febrero       Marzo       Abril        Mayo       Junio       Julio
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5      459.15      505.58      545.94      617.19      698.16      756.05
# 6      172.29      176.24      185.36      193.13      196.65      207.44
# 7      226.87      242.47      269.86      318.44      358.85      403.18
# 8      221.36      235.67      247.65      278.12      308.03      327.01
# 9     1013.04     1047.42     1097.26     1146.09     1172.34     1221.66
#
#   Unnamed: 83 Unnamed: 84 Unnamed: 85 Unnamed: 86 Unnamed: 87  Unnamed: 88  \
# 0         NaN         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN         NaN          NaN
# 2      Agosto  Septiembre     Octubre   Noviembre   Diciembre          NaN
# 3         NaN         NaN         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN         NaN         NaN          NaN
# 5      861.81       980.2     1076.98     1244.72     1534.79          NaN
# 6      222.91      241.22      269.52      323.26      492.38          NaN
# 7       460.4      582.04      789.18     1020.69     1557.53          NaN
# 8      347.03      391.36      516.94      760.44      991.66          NaN
# 9     1702.55     1972.69     2065.09      2345.9     3142.87          NaN
#
#   Unnamed: 89 Unnamed: 90 Unnamed: 91 Unnamed: 92 Unnamed: 93 Unnamed: 94  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1    Año 2024         NaN         NaN         NaN         NaN         NaN
# 2       Enero     Febrero       Marzo       Abril        Mayo       Junio
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5     1790.62     1942.55     2214.07     2376.84     2501.86      2597.5
# 6      665.79      741.12      818.97      816.97      786.85      828.26
# 7     2046.61     2355.31     2445.35     2422.83     2351.11     2336.91
# 8     1125.02     1260.22     1304.62     1359.24      1399.7     1371.32
# 9      3469.9      3807.3     4193.13     4441.39     4673.95     4837.91
#
#   Unnamed: 95 Unnamed: 96 Unnamed: 97 Unnamed: 98 Unnamed: 99
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2       Julio      Agosto  Septiembre     Octubre   Noviembre
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
# 5     2663.51     2774.95     2878.01     2948.01     3040.97
# 6      851.77      829.47      829.22       815.9      830.61
# 7     2301.88     2288.26        2262     2285.88     2273.69
# 8      1396.5     1431.34     1394.23     1374.73     1382.81
# 9     4883.83     4913.59      4934.2     4918.39     5020.98

# %% [markdown]
# ### Hay 3 filas nulas, antes de comenzar los datos. Que solo contienen el texto, "peso", es irrelevante para el analisis, seran eliminadas.

# %%
# Selecciona las filas 3 y 4
filas_seleccionadas = nacional.iloc[[0,3,4]]

# Identifica las columnas no nulas (en al menos una de las filas seleccionadas)
columnas_no_nulas = filas_seleccionadas.columns[filas_seleccionadas.notnull().any()]

# Filtra solo las columnas no nulas
resultado = filas_seleccionadas[columnas_no_nulas]

print("Columnas no nulas:", columnas_no_nulas.tolist())
print("Datos de las filas seleccionadas:")
print(resultado)
# Out:
# Columnas no nulas: ['Unnamed: 3']
# Datos de las filas seleccionadas:
#   Unnamed: 3
# 0        NaN
# 3      Pesos
# 4        NaN

# %%
# LLamar solo las filas necesarias 
nacional = nacional.iloc[:89]
nacional.tail(1) # Ver si abarca la ultilma fila.
# Out:
#    Precios al consumidor de una selección de alimentos, bebidas y otros artículos de la canasta del Índice de precios al consumidor, según regiones. Junio 2017- noviembre 2024  \
# 88                                          Patagonia
#
#           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 88  Jabón de tocador      125 g      15.09       15.3       15.6      15.58
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 88      15.68      15.58      15.74          NaN       15.89       16.19
#
#    Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 88       16.51       16.79       16.91       18.25          19       20.01
#
#    Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  Unnamed: 23 Unnamed: 24  \
# 88       21.86       23.66       24.75       24.98          NaN       26.86
#
#    Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 88       28.41       29.05       30.01       31.41       31.97        32.8
#
#    Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  Unnamed: 36  \
# 88       34.76       37.11       39.02       42.42       44.58          NaN
#
#    Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# 88       46.27       47.18         ///       46.59        48.8        48.4
#
#    Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47 Unnamed: 48  \
# 88          49       49.96        50.5       50.96       52.58       52.88
#
#     Unnamed: 49 Unnamed: 50 Unnamed: 51 Unnamed: 52 Unnamed: 53 Unnamed: 54  \
# 88          NaN       54.18       54.11       54.29   54.511006   56.110862
#
#    Unnamed: 55 Unnamed: 56 Unnamed: 57 Unnamed: 58 Unnamed: 59 Unnamed: 60  \
# 88    58.05568   60.366044   61.943983       63.97       64.91        67.5
#
#    Unnamed: 61  Unnamed: 62 Unnamed: 63 Unnamed: 64 Unnamed: 65 Unnamed: 66  \
# 88       70.33          NaN       73.82       79.87       87.15       90.81
#
#    Unnamed: 67 Unnamed: 68 Unnamed: 69 Unnamed: 70 Unnamed: 71 Unnamed: 72  \
# 88       97.02       103.8      115.81      129.03      142.68      156.12
#
#    Unnamed: 73 Unnamed: 74  Unnamed: 75 Unnamed: 76 Unnamed: 77 Unnamed: 78  \
# 88      165.94      176.19          NaN      190.05      200.22       205.2
#
#    Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84  \
# 88      218.15      229.81      241.43      255.59      278.89      304.66
#
#    Unnamed: 85 Unnamed: 86 Unnamed: 87  Unnamed: 88 Unnamed: 89 Unnamed: 90  \
# 88      320.42      347.99      475.26          NaN      714.94      817.54
#
#    Unnamed: 91 Unnamed: 92 Unnamed: 93 Unnamed: 94 Unnamed: 95 Unnamed: 96  \
# 88      844.65      880.49      913.33      909.57      904.17      915.87
#
#    Unnamed: 97 Unnamed: 98 Unnamed: 99
# 88      957.23      998.82      1011.4

# %%
# Elimina las filas 0, 3 y 4 del DataFrame original
nacional = nacional.drop(index=[0,3, 4])
# La primera fila como columnas.
nacional.columns = nacional.iloc[0]
nacional = nacional[1:] # Quitar la pprimera fila, ya que ahora es columna
nacional.head(3)
# Out:
# 1 Región Productos seleccionados Unidad de medida Año 2017    NaN     NaN  \
# 2    NaN                     NaN              NaN    Junio  Julio  Agosto
# 5    GBA             Pan francés               kg    38.64  39.12   39.43
# 6    GBA   Harina de trigo común               kg    10.67  10.61   10.65
#
# 1         NaN      NaN        NaN        NaN NaN Año 2018      NaN    NaN  \
# 2  Septiembre  Octubre  Noviembre  Diciembre NaN    Enero  Febrero  Marzo
# 5       39.71    39.89      40.24      40.55 NaN    41.29    42.62  44.38
# 6       10.66    10.61      10.81      11.03 NaN     11.2    11.64  11.94
#
# 1    NaN    NaN    NaN    NaN     NaN         NaN      NaN        NaN  \
# 2  Abril   Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre
# 5  45.83  49.81  55.19  57.05   57.61       67.25     71.9      72.63
# 6  12.72  16.69  20.99  23.35   24.09       26.92    29.19      30.23
#
# 1        NaN NaN Año 2019      NaN    NaN    NaN    NaN    NaN    NaN     NaN  \
# 2  Diciembre NaN    Enero  Febrero  Marzo  Abril   Mayo  Junio  Julio  Agosto
# 5      73.49 NaN    75.04    76.94   79.9  81.56  83.89  87.52  88.68   92.16
# 6      30.32 NaN    30.81    31.28  31.56  31.69  33.15   34.3  34.85   36.04
#
# 1         NaN      NaN        NaN        NaN NaN Año 2020      NaN     NaN  \
# 2  Septiembre  Octubre  Noviembre  Diciembre NaN   Enero   Febrero   Marzo
# 5       98.61   100.62     106.12     108.02 NaN   111.25   112.99  116.37
# 6       38.34     38.9      39.48      40.24 NaN    42.07    43.62   43.43
#
# 1     NaN     NaN     NaN     NaN     NaN         NaN      NaN        NaN  \
# 2   Abril    Mayo   Junio   Julio  Agosto  Septiembre  Octubre  Noviembre
# 5  116.52  113.97  116.46  116.71  116.91      127.31    132.1     138.31
# 6    43.7   44.22   44.41   45.62   46.04       46.12    47.66      45.17
#
# 1        NaN NaN Año 2021      NaN     NaN         NaN         NaN  \
# 2  Diciembre NaN    Enero  Febrero   Marzo       Abril        Mayo
# 5     140.13 NaN   145.61   151.12  157.27  164.717943  172.293019
# 6      42.55 NaN    43.62    45.06   45.12   46.399629   49.505956
#
# 1         NaN         NaN         NaN         NaN      NaN        NaN  \
# 2       Junio       Julio      Agosto  Septiembre  Octubre  Noviembre
# 5  182.910621  185.115699  188.621431      190.09   197.99     204.32
# 6   50.938056   52.709116   53.547283       56.83    59.29      59.37
#
# 1        NaN NaN Año 2022      NaN     NaN     NaN     NaN    NaN     NaN  \
# 2  Diciembre NaN    Enero  Febrero   Marzo   Abril    Mayo  Junio   Julio
# 5     207.97 NaN   209.92   225.82  265.71  295.24  301.62  311.8  327.39
# 6      59.46 NaN    62.82    65.55   74.22   86.18   95.25  95.24  107.06
#
# 1     NaN         NaN      NaN        NaN        NaN NaN Año 2023      NaN  \
# 2  Agosto  Septiembre  Octubre  Noviembre  Diciembre NaN    Enero  Febrero
# 5   343.1      366.54    385.2     407.77     428.42 NaN   435.66   459.15
# 6  114.41      123.46   132.37      140.7     146.91 NaN   160.14   172.29
#
# 1     NaN     NaN     NaN     NaN     NaN     NaN         NaN      NaN  \
# 2   Marzo   Abril    Mayo   Junio   Julio  Agosto  Septiembre  Octubre
# 5  505.58  545.94  617.19  698.16  756.05  861.81       980.2  1076.98
# 6  176.24  185.36  193.13  196.65  207.44  222.91      241.22   269.52
#
# 1        NaN        NaN NaN Año 2024      NaN      NaN      NaN      NaN  \
# 2  Noviembre  Diciembre NaN    Enero  Febrero    Marzo    Abril     Mayo
# 5    1244.72    1534.79 NaN  1790.62  1942.55  2214.07  2376.84  2501.86
# 6     323.26     492.38 NaN   665.79   741.12   818.97   816.97   786.85
#
# 1     NaN      NaN      NaN         NaN      NaN        NaN
# 2   Junio    Julio   Agosto  Septiembre  Octubre  Noviembre
# 5  2597.5  2663.51  2774.95     2878.01  2948.01    3040.97
# 6  828.26   851.77   829.47      829.22    815.9     830.61

# %%
nacional['temporal'] = 'temporal'
nacional.insert(3, 'temporal-d', np.nan) # Insertar columna temporal para desplazar los datos

# Desplazar los datos hacia la derecha desde la columna 3
nacional.iloc[:, 4:] = nacional.iloc[:, 3:-1].values  # Mover los datos hacia la derecha
nacional = nacional.drop(nacional.columns[3], axis=1)  # Borrar la cuarta columna

# Asignar los años a la columna del año.
for año in range(2017, 2025):
    nacional[f'Año {año}'] = año
    
# Mostrar el DataFrame resultante
nacional.head(3)
# Out:
# 1 Región Productos seleccionados Unidad de medida  Año 2017    NaN    NaN  \
# 2    NaN                     NaN              NaN      2017  Junio  Julio
# 5    GBA             Pan francés               kg      2017  38.64  39.12
# 6    GBA   Harina de trigo común               kg      2017  10.67  10.61
#
# 1     NaN         NaN      NaN        NaN        NaN  Año 2018    NaN  \
# 2  Agosto  Septiembre  Octubre  Noviembre  Diciembre      2018  Enero
# 5   39.43       39.71    39.89      40.24      40.55      2018  41.29
# 6   10.65       10.66    10.61      10.81      11.03      2018   11.2
#
# 1      NaN    NaN    NaN    NaN    NaN    NaN     NaN         NaN      NaN  \
# 2  Febrero  Marzo  Abril   Mayo  Junio  Julio  Agosto  Septiembre  Octubre
# 5    42.62  44.38  45.83  49.81  55.19  57.05   57.61       67.25     71.9
# 6    11.64  11.94  12.72  16.69  20.99  23.35   24.09       26.92    29.19
#
# 1        NaN        NaN  Año 2019    NaN      NaN    NaN    NaN    NaN    NaN  \
# 2  Noviembre  Diciembre      2019  Enero  Febrero  Marzo  Abril   Mayo  Junio
# 5      72.63      73.49      2019  75.04    76.94   79.9  81.56  83.89  87.52
# 6      30.23      30.32      2019  30.81    31.28  31.56  31.69  33.15   34.3
#
# 1    NaN     NaN         NaN      NaN        NaN        NaN  Año 2020     NaN  \
# 2  Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre      2020  Enero
# 5  88.68   92.16       98.61   100.62     106.12     108.02      2020  111.25
# 6  34.85   36.04       38.34     38.9      39.48      40.24      2020   42.07
#
# 1      NaN     NaN     NaN     NaN     NaN     NaN     NaN         NaN  \
# 2  Febrero   Marzo   Abril    Mayo   Junio   Julio  Agosto  Septiembre
# 5   112.99  116.37  116.52  113.97  116.46  116.71  116.91      127.31
# 6    43.62   43.43    43.7   44.22   44.41   45.62   46.04       46.12
#
# 1      NaN        NaN        NaN  Año 2021     NaN      NaN     NaN  \
# 2  Octubre  Noviembre  Diciembre      2021   Enero  Febrero   Marzo
# 5    132.1     138.31     140.13      2021  145.61   151.12  157.27
# 6    47.66      45.17      42.55      2021   43.62    45.06   45.12
#
# 1         NaN         NaN         NaN         NaN         NaN         NaN  \
# 2       Abril        Mayo       Junio       Julio      Agosto  Septiembre
# 5  164.717943  172.293019  182.910621  185.115699  188.621431      190.09
# 6   46.399629   49.505956   50.938056   52.709116   53.547283       56.83
#
# 1      NaN        NaN        NaN  Año 2022     NaN      NaN     NaN     NaN  \
# 2  Octubre  Noviembre  Diciembre      2022   Enero  Febrero   Marzo   Abril
# 5   197.99     204.32     207.97      2022  209.92   225.82  265.71  295.24
# 6    59.29      59.37      59.46      2022   62.82    65.55   74.22   86.18
#
# 1     NaN    NaN     NaN     NaN         NaN      NaN        NaN        NaN  \
# 2    Mayo  Junio   Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre
# 5  301.62  311.8  327.39   343.1      366.54    385.2     407.77     428.42
# 6   95.25  95.24  107.06  114.41      123.46   132.37      140.7     146.91
#
# 1  Año 2023     NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN  \
# 2      2023   Enero  Febrero   Marzo   Abril    Mayo   Junio   Julio  Agosto
# 5      2023  435.66   459.15  505.58  545.94  617.19  698.16  756.05  861.81
# 6      2023  160.14   172.29  176.24  185.36  193.13  196.65  207.44  222.91
#
# 1         NaN      NaN        NaN        NaN  Año 2024      NaN      NaN  \
# 2  Septiembre  Octubre  Noviembre  Diciembre      2024    Enero  Febrero
# 5       980.2  1076.98    1244.72    1534.79      2024  1790.62  1942.55
# 6      241.22   269.52     323.26     492.38      2024   665.79   741.12
#
# 1      NaN      NaN      NaN     NaN      NaN      NaN         NaN      NaN  \
# 2    Marzo    Abril     Mayo   Junio    Julio   Agosto  Septiembre  Octubre
# 5  2214.07  2376.84  2501.86  2597.5  2663.51  2774.95     2878.01  2948.01
# 6   818.97   816.97   786.85  828.26   851.77   829.47      829.22    815.9
#
# 1   temporal
# 2  Noviembre
# 5    3040.97
# 6     830.61

# %%
# Extraer los años de las cabeceras de las columnas
years = nacional.columns[3:].values  # A partir de la cuarta columna
print(f'Años: {years}')
# Extraer los meses de la primera fila
months = nacional.iloc[0, 3:].values  # A partir de la cuarta columna
print(f'Meses: {months}')
# Out:
# Años: ['Año 2017' nan nan nan nan nan nan np.float64(nan) 'Año 2018' nan nan nan
#  nan nan nan nan nan nan nan nan np.float64(nan) 'Año 2019' nan nan nan
#  nan nan nan nan nan nan nan nan np.float64(nan) 'Año 2020' nan nan nan
#  nan nan nan nan nan nan nan nan np.float64(nan) 'Año 2021' nan nan nan
#  nan nan nan nan nan nan nan nan np.float64(nan) 'Año 2022' nan nan nan
#  nan nan nan nan nan nan nan nan np.float64(nan) 'Año 2023' nan nan nan
#  nan nan nan nan nan nan nan nan np.float64(nan) 'Año 2024' nan nan nan
#  nan nan nan nan nan nan nan 'temporal']
# Meses: [np.int64(2017) 'Junio' 'Julio' 'Agosto' 'Septiembre' 'Octubre'
#  'Noviembre' 'Diciembre' np.int64(2018) 'Enero' 'Febrero' 'Marzo' 'Abril'
#  'Mayo' 'Junio' 'Julio' 'Agosto' 'Septiembre' 'Octubre' 'Noviembre'
#  'Diciembre' np.int64(2019) 'Enero' 'Febrero' 'Marzo' 'Abril' 'Mayo'
#  'Junio' 'Julio' 'Agosto' 'Septiembre' 'Octubre' 'Noviembre' 'Diciembre'
#  np.int64(2020) 'Enero ' 'Febrero' 'Marzo' 'Abril' 'Mayo' 'Junio' 'Julio'
#  'Agosto' 'Septiembre' 'Octubre' 'Noviembre' 'Diciembre' np.int64(2021)
#  'Enero' 'Febrero' 'Marzo' 'Abril' 'Mayo' 'Junio' 'Julio' 'Agosto'
#  'Septiembre' 'Octubre' 'Noviembre' 'Diciembre' np.int64(2022) 'Enero'
#  'Febrero' 'Marzo' 'Abril' 'Mayo' 'Junio' 'Julio' 'Agosto' 'Septiembre'
#  'Octubre' 'Noviembre' 'Diciembre' np.int64(2023) 'Enero' 'Febrero'
#  'Marzo' 'Abril' 'Mayo' 'Junio' 'Julio' 'Agosto' 'Septiembre' 'Octubre'
#  'Noviembre' 'Diciembre' np.int64(2024) 'Enero' 'Febrero' 'Marzo' 'Abril'
#  'Mayo' 'Junio' 'Julio' 'Agosto' 'Septiembre' 'Octubre' 'Noviembre']

# %%
# Lista para almacenar las filas del DataFrame final
rows = []

# Mapeo manual de nombres de meses en español a números
meses_espanol = {
    "Enero": 1, "Febrero": 2, "Marzo": 3, "Abril": 4, "Mayo": 5, "Junio": 6,
    "Julio": 7, "Agosto": 8, "Septiembre": 9, "Octubre": 10, "Noviembre": 11, "Diciembre": 12
}

# Variable para almacenar el año actual
current_year = None

# Iterar sobre las filas de productos, regiones y unidades
for i in range(1, len(nacional)):  # Empezar desde la segunda fila (datos de precios)
    region = nacional.iloc[i, 0]  # Columna "Region"
    producto = nacional.iloc[i, 1]  # Columna "Productos seleccionados"
    unidad = nacional.iloc[i, 2]  # Columna "Unidad de medida"
    
    print(f"\nfila {i}:")  # Depuración: Verificar la fila actual
    print(f"Region: {region}, Producto: {producto}, Unidad: {unidad}")  # Depuración: Verificar los valores
    
    # Iterar sobre las columnas de años y meses
    for j in range(len(years)):
        year = years[j]  # Año correspondiente a la columna
        month = months[j]  # Mes correspondiente a la columna
        price = nacional.iloc[i, j + 3]  # Precio correspondiente (columna j + 3)
        
        print(f"\nColumna {j}:")  # Depuración: Verificar la columna actual
        print(f"Año: {year}, Mes: {month}, Precio: {price}")  # Depuración: Verificar los valores
        
        # Si la columna es un año (por ejemplo, "Año 2017"), actualizar el año actual
        if isinstance(year, str) and year.startswith("Año "):
            try:
                current_year = int(year.replace("Año ", "").strip())
                print(f"Año actual actualizado: {current_year}")  # Depuración
            except ValueError:
                print("Saltando columna: año no es un número válido.")  # Depuración
            continue  # Saltar esta columna, ya que no contiene un mes
        
        # Si el mes no es una cadena, saltar esta columna
        if not isinstance(month, str):
            print("Saltando columna: mes no es una cadena.")  # Depuración
            continue
        
        # Limpiar el nombre del mes (eliminar espacios adicionales)
        month_cleaned = month.strip().capitalize()
        
        # Convertir el mes a número usando el mapeo manual
        month_number = meses_espanol.get(month_cleaned)
        if month_number is None:
            print(f"Saltando columna: mes '{month_cleaned}' no reconocido.")  # Depuración
            continue
        
        # Si no hay un año actual, saltar esta columna
        if current_year is None:
            print("Saltando columna: no hay un año actual.")  # Depuración
            continue
        
        # Construir la fecha en formato yyyy-mm-dd (asumiendo el primer día del mes)
        date = f"{current_year}-{month_number:02d}-01"
        print(f"Fecha construida: {date}")  # Depuración: Verificar la fecha
        
        # Agregar una fila a la lista
        rows.append([region, producto, unidad, date, price])
        print("Fila agregada:", [region, producto, unidad, date, price])  # Depuración: Verificar la fila agregada

# Crear el DataFrame final
final_df = pd.DataFrame(rows, columns=["Region", "Productos seleccionados", "Unidad de medida", "Date", "Price"])
# Reordenar y renombrar las columnas
final_df = final_df[["Date", "Region", "Productos seleccionados", "Unidad de medida", "Price"]]
final_df.columns = ["Date", "Region", "Product", "Unit", "Price"]
# Out:
# fila 1:
# Region: GBA, Producto: Pan francés, Unidad: kg
#
# Columna 0:
# Año: Año 2017, Mes: 2017, Precio: 2017
# Año actual actualizado: 2017
#
# Columna 1:
# Año: nan, Mes: Junio, Precio: 38.64
# Fecha construida: 2017-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2017-06-01', 38.64]
#
# Columna 2:
# Año: nan, Mes: Julio, Precio: 39.12
# Fecha construida: 2017-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2017-07-01', 39.12]
#
# Columna 3:
# Año: nan, Mes: Agosto, Precio: 39.43
# Fecha construida: 2017-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2017-08-01', 39.43]
#
# Columna 4:
# Año: nan, Mes: Septiembre, Precio: 39.71
# Fecha construida: 2017-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2017-09-01', 39.71]
#
# Columna 5:
# Año: nan, Mes: Octubre, Precio: 39.89
# Fecha construida: 2017-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2017-10-01', 39.89]
#
# Columna 6:
# Año: nan, Mes: Noviembre, Precio: 40.24
# Fecha construida: 2017-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2017-11-01', 40.24]
#
# Columna 7:
# Año: nan, Mes: Diciembre, Precio: 40.55
# Fecha construida: 2017-12-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2017-12-01', 40.55]
#
# Columna 8:
# Año: Año 2018, Mes: 2018, Precio: 2018
# Año actual actualizado: 2018
#
# Columna 9:
# Año: nan, Mes: Enero, Precio: 41.29
# Fecha construida: 2018-01-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-01-01', 41.29]
#
# Columna 10:
# Año: nan, Mes: Febrero, Precio: 42.62
# Fecha construida: 2018-02-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-02-01', 42.62]
#
# Columna 11:
# Año: nan, Mes: Marzo, Precio: 44.38
# Fecha construida: 2018-03-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-03-01', 44.38]
#
# Columna 12:
# Año: nan, Mes: Abril, Precio: 45.83
# Fecha construida: 2018-04-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-04-01', 45.83]
#
# Columna 13:
# Año: nan, Mes: Mayo, Precio: 49.81
# Fecha construida: 2018-05-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-05-01', 49.81]
#
# Columna 14:
# Año: nan, Mes: Junio, Precio: 55.19
# Fecha construida: 2018-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-06-01', 55.19]
#
# Columna 15:
# Año: nan, Mes: Julio, Precio: 57.05
# Fecha construida: 2018-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-07-01', 57.05]
#
# Columna 16:
# Año: nan, Mes: Agosto, Precio: 57.61
# Fecha construida: 2018-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-08-01', 57.61]
#
# Columna 17:
# Año: nan, Mes: Septiembre, Precio: 67.25
# Fecha construida: 2018-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-09-01', 67.25]
#
# Columna 18:
# Año: nan, Mes: Octubre, Precio: 71.9
# Fecha construida: 2018-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-10-01', 71.9]
#
# Columna 19:
# Año: nan, Mes: Noviembre, Precio: 72.63
# Fecha construida: 2018-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-11-01', 72.63]
#
# Columna 20:
# Año: nan, Mes: Diciembre, Precio: 73.49
# Fecha construida: 2018-12-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2018-12-01', 73.49]
#
# Columna 21:
# Año: Año 2019, Mes: 2019, Precio: 2019
# Año actual actualizado: 2019
#
# Columna 22:
# Año: nan, Mes: Enero, Precio: 75.04
# Fecha construida: 2019-01-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-01-01', 75.04]
#
# Columna 23:
# Año: nan, Mes: Febrero, Precio: 76.94
# Fecha construida: 2019-02-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-02-01', 76.94]
#
# Columna 24:
# Año: nan, Mes: Marzo, Precio: 79.9
# Fecha construida: 2019-03-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-03-01', 79.9]
#
# Columna 25:
# Año: nan, Mes: Abril, Precio: 81.56
# Fecha construida: 2019-04-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-04-01', 81.56]
#
# Columna 26:
# Año: nan, Mes: Mayo, Precio: 83.89
# Fecha construida: 2019-05-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-05-01', 83.89]
#
# Columna 27:
# Año: nan, Mes: Junio, Precio: 87.52
# Fecha construida: 2019-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-06-01', 87.52]
#
# Columna 28:
# Año: nan, Mes: Julio, Precio: 88.68
# Fecha construida: 2019-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-07-01', 88.68]
#
# Columna 29:
# Año: nan, Mes: Agosto, Precio: 92.16
# Fecha construida: 2019-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-08-01', 92.16]
#
# Columna 30:
# Año: nan, Mes: Septiembre, Precio: 98.61
# Fecha construida: 2019-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-09-01', 98.61]
#
# Columna 31:
# Año: nan, Mes: Octubre, Precio: 100.62
# Fecha construida: 2019-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-10-01', 100.62]
#
# Columna 32:
# Año: nan, Mes: Noviembre, Precio: 106.12
# Fecha construida: 2019-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-11-01', 106.12]
#
# Columna 33:
# Año: nan, Mes: Diciembre, Precio: 108.02
# Fecha construida: 2019-12-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2019-12-01', 108.02]
#
# Columna 34:
# Año: Año 2020, Mes: 2020, Precio: 2020
# Año actual actualizado: 2020
#
# Columna 35:
# Año: nan, Mes: Enero , Precio: 111.25
# Fecha construida: 2020-01-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-01-01', 111.25]
#
# Columna 36:
# Año: nan, Mes: Febrero, Precio: 112.99
# Fecha construida: 2020-02-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-02-01', 112.99]
#
# Columna 37:
# Año: nan, Mes: Marzo, Precio: 116.37
# Fecha construida: 2020-03-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-03-01', 116.37]
#
# Columna 38:
# Año: nan, Mes: Abril, Precio: 116.52
# Fecha construida: 2020-04-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-04-01', 116.52]
#
# Columna 39:
# Año: nan, Mes: Mayo, Precio: 113.97
# Fecha construida: 2020-05-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-05-01', 113.97]
#
# Columna 40:
# Año: nan, Mes: Junio, Precio: 116.46
# Fecha construida: 2020-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-06-01', 116.46]
#
# Columna 41:
# Año: nan, Mes: Julio, Precio: 116.71
# Fecha construida: 2020-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-07-01', 116.71]
#
# Columna 42:
# Año: nan, Mes: Agosto, Precio: 116.91
# Fecha construida: 2020-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-08-01', 116.91]
#
# Columna 43:
# Año: nan, Mes: Septiembre, Precio: 127.31
# Fecha construida: 2020-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-09-01', 127.31]
#
# Columna 44:
# Año: nan, Mes: Octubre, Precio: 132.1
# Fecha construida: 2020-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-10-01', 132.1]
#
# Columna 45:
# Año: nan, Mes: Noviembre, Precio: 138.31
# Fecha construida: 2020-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-11-01', 138.31]
#
# Columna 46:
# Año: nan, Mes: Diciembre, Precio: 140.13
# Fecha construida: 2020-12-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2020-12-01', 140.13]
#
# Columna 47:
# Año: Año 2021, Mes: 2021, Precio: 2021
# Año actual actualizado: 2021
#
# Columna 48:
# Año: nan, Mes: Enero, Precio: 145.61
# Fecha construida: 2021-01-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-01-01', 145.61]
#
# Columna 49:
# Año: nan, Mes: Febrero, Precio: 151.12
# Fecha construida: 2021-02-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-02-01', 151.12]
#
# Columna 50:
# Año: nan, Mes: Marzo, Precio: 157.27
# Fecha construida: 2021-03-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-03-01', 157.27]
#
# Columna 51:
# Año: nan, Mes: Abril, Precio: 164.717942940625
# Fecha construida: 2021-04-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-04-01', 164.717942940625]
#
# Columna 52:
# Año: nan, Mes: Mayo, Precio: 172.293018932874
# Fecha construida: 2021-05-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-05-01', 172.293018932874]
#
# Columna 53:
# Año: nan, Mes: Junio, Precio: 182.910621066996
# Fecha construida: 2021-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-06-01', 182.910621066996]
#
# Columna 54:
# Año: nan, Mes: Julio, Precio: 185.115698554028
# Fecha construida: 2021-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-07-01', 185.115698554028]
#
# Columna 55:
# Año: nan, Mes: Agosto, Precio: 188.621431134082
# Fecha construida: 2021-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-08-01', 188.621431134082]
#
# Columna 56:
# Año: nan, Mes: Septiembre, Precio: 190.09
# Fecha construida: 2021-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-09-01', 190.09]
#
# Columna 57:
# Año: nan, Mes: Octubre, Precio: 197.99
# Fecha construida: 2021-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-10-01', 197.99]
#
# Columna 58:
# Año: nan, Mes: Noviembre, Precio: 204.32
# Fecha construida: 2021-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-11-01', 204.32]
#
# Columna 59:
# Año: nan, Mes: Diciembre, Precio: 207.97
# Fecha construida: 2021-12-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2021-12-01', 207.97]
#
# Columna 60:
# Año: Año 2022, Mes: 2022, Precio: 2022
# Año actual actualizado: 2022
#
# Columna 61:
# Año: nan, Mes: Enero, Precio: 209.92
# Fecha construida: 2022-01-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-01-01', 209.92]
#
# Columna 62:
# Año: nan, Mes: Febrero, Precio: 225.82
# Fecha construida: 2022-02-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-02-01', 225.82]
#
# Columna 63:
# Año: nan, Mes: Marzo, Precio: 265.71
# Fecha construida: 2022-03-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-03-01', 265.71]
#
# Columna 64:
# Año: nan, Mes: Abril, Precio: 295.24
# Fecha construida: 2022-04-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-04-01', 295.24]
#
# Columna 65:
# Año: nan, Mes: Mayo, Precio: 301.62
# Fecha construida: 2022-05-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-05-01', 301.62]
#
# Columna 66:
# Año: nan, Mes: Junio, Precio: 311.8
# Fecha construida: 2022-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-06-01', 311.8]
#
# Columna 67:
# Año: nan, Mes: Julio, Precio: 327.39
# Fecha construida: 2022-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-07-01', 327.39]
#
# Columna 68:
# Año: nan, Mes: Agosto, Precio: 343.1
# Fecha construida: 2022-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-08-01', 343.1]
#
# Columna 69:
# Año: nan, Mes: Septiembre, Precio: 366.54
# Fecha construida: 2022-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-09-01', 366.54]
#
# Columna 70:
# Año: nan, Mes: Octubre, Precio: 385.2
# Fecha construida: 2022-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-10-01', 385.2]
#
# Columna 71:
# Año: nan, Mes: Noviembre, Precio: 407.77
# Fecha construida: 2022-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-11-01', 407.77]
#
# Columna 72:
# Año: nan, Mes: Diciembre, Precio: 428.42
# Fecha construida: 2022-12-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2022-12-01', 428.42]
#
# Columna 73:
# Año: Año 2023, Mes: 2023, Precio: 2023
# Año actual actualizado: 2023
#
# Columna 74:
# Año: nan, Mes: Enero, Precio: 435.66
# Fecha construida: 2023-01-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-01-01', 435.66]
#
# Columna 75:
# Año: nan, Mes: Febrero, Precio: 459.15
# Fecha construida: 2023-02-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-02-01', 459.15]
#
# Columna 76:
# Año: nan, Mes: Marzo, Precio: 505.58
# Fecha construida: 2023-03-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-03-01', 505.58]
#
# Columna 77:
# Año: nan, Mes: Abril, Precio: 545.94
# Fecha construida: 2023-04-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-04-01', 545.94]
#
# Columna 78:
# Año: nan, Mes: Mayo, Precio: 617.19
# Fecha construida: 2023-05-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-05-01', 617.19]
#
# Columna 79:
# Año: nan, Mes: Junio, Precio: 698.16
# Fecha construida: 2023-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-06-01', 698.16]
#
# Columna 80:
# Año: nan, Mes: Julio, Precio: 756.05
# Fecha construida: 2023-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-07-01', 756.05]
#
# Columna 81:
# Año: nan, Mes: Agosto, Precio: 861.81
# Fecha construida: 2023-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-08-01', 861.81]
#
# Columna 82:
# Año: nan, Mes: Septiembre, Precio: 980.2
# Fecha construida: 2023-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-09-01', 980.2]
#
# Columna 83:
# Año: nan, Mes: Octubre, Precio: 1076.98
# Fecha construida: 2023-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-10-01', 1076.98]
#
# Columna 84:
# Año: nan, Mes: Noviembre, Precio: 1244.72
# Fecha construida: 2023-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-11-01', 1244.72]
#
# Columna 85:
# Año: nan, Mes: Diciembre, Precio: 1534.79
# Fecha construida: 2023-12-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2023-12-01', 1534.79]
#
# Columna 86:
# Año: Año 2024, Mes: 2024, Precio: 2024
# Año actual actualizado: 2024
#
# Columna 87:
# Año: nan, Mes: Enero, Precio: 1790.62
# Fecha construida: 2024-01-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-01-01', 1790.62]
#
# Columna 88:
# Año: nan, Mes: Febrero, Precio: 1942.55
# Fecha construida: 2024-02-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-02-01', 1942.55]
#
# Columna 89:
# Año: nan, Mes: Marzo, Precio: 2214.07
# Fecha construida: 2024-03-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-03-01', 2214.07]
#
# Columna 90:
# Año: nan, Mes: Abril, Precio: 2376.84
# Fecha construida: 2024-04-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-04-01', 2376.84]
#
# Columna 91:
# Año: nan, Mes: Mayo, Precio: 2501.86
# Fecha construida: 2024-05-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-05-01', 2501.86]
#
# Columna 92:
# Año: nan, Mes: Junio, Precio: 2597.5
# Fecha construida: 2024-06-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-06-01', 2597.5]
#
# Columna 93:
# Año: nan, Mes: Julio, Precio: 2663.51
# Fecha construida: 2024-07-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-07-01', 2663.51]
#
# Columna 94:
# Año: nan, Mes: Agosto, Precio: 2774.95
# Fecha construida: 2024-08-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-08-01', 2774.95]
#
# Columna 95:
# Año: nan, Mes: Septiembre, Precio: 2878.01
# Fecha construida: 2024-09-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-09-01', 2878.01]
#
# Columna 96:
# Año: nan, Mes: Octubre, Precio: 2948.01
# Fecha construida: 2024-10-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-10-01', 2948.01]
#
# Columna 97:
# Año: temporal, Mes: Noviembre, Precio: 3040.97
# Fecha construida: 2024-11-01
# Fila agregada: ['GBA', 'Pan francés', 'kg', '2024-11-01', 3040.97]
#
# fila 2:
# Region: GBA, Producto: Harina de trigo común, Unidad: kg
#
# Columna 0:
# Año: Año 2017, Mes: 2017, Precio: 2017
# Año actual actualizado: 2017
#
# Columna 1:
# Año: nan, Mes: Junio, Precio: 10.67
# Fecha construida: 2017-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2017-06-01', 10.67]
#
# Columna 2:
# Año: nan, Mes: Julio, Precio: 10.61
# Fecha construida: 2017-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2017-07-01', 10.61]
#
# Columna 3:
# Año: nan, Mes: Agosto, Precio: 10.65
# Fecha construida: 2017-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2017-08-01', 10.65]
#
# Columna 4:
# Año: nan, Mes: Septiembre, Precio: 10.66
# Fecha construida: 2017-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2017-09-01', 10.66]
#
# Columna 5:
# Año: nan, Mes: Octubre, Precio: 10.61
# Fecha construida: 2017-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2017-10-01', 10.61]
#
# Columna 6:
# Año: nan, Mes: Noviembre, Precio: 10.81
# Fecha construida: 2017-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2017-11-01', 10.81]
#
# Columna 7:
# Año: nan, Mes: Diciembre, Precio: 11.03
# Fecha construida: 2017-12-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2017-12-01', 11.03]
#
# Columna 8:
# Año: Año 2018, Mes: 2018, Precio: 2018
# Año actual actualizado: 2018
#
# Columna 9:
# Año: nan, Mes: Enero, Precio: 11.2
# Fecha construida: 2018-01-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-01-01', 11.2]
#
# Columna 10:
# Año: nan, Mes: Febrero, Precio: 11.64
# Fecha construida: 2018-02-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-02-01', 11.64]
#
# Columna 11:
# Año: nan, Mes: Marzo, Precio: 11.94
# Fecha construida: 2018-03-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-03-01', 11.94]
#
# Columna 12:
# Año: nan, Mes: Abril, Precio: 12.72
# Fecha construida: 2018-04-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-04-01', 12.72]
#
# Columna 13:
# Año: nan, Mes: Mayo, Precio: 16.69
# Fecha construida: 2018-05-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-05-01', 16.69]
#
# Columna 14:
# Año: nan, Mes: Junio, Precio: 20.99
# Fecha construida: 2018-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-06-01', 20.99]
#
# Columna 15:
# Año: nan, Mes: Julio, Precio: 23.35
# Fecha construida: 2018-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-07-01', 23.35]
#
# Columna 16:
# Año: nan, Mes: Agosto, Precio: 24.09
# Fecha construida: 2018-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-08-01', 24.09]
#
# Columna 17:
# Año: nan, Mes: Septiembre, Precio: 26.92
# Fecha construida: 2018-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-09-01', 26.92]
#
# Columna 18:
# Año: nan, Mes: Octubre, Precio: 29.19
# Fecha construida: 2018-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-10-01', 29.19]
#
# Columna 19:
# Año: nan, Mes: Noviembre, Precio: 30.23
# Fecha construida: 2018-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-11-01', 30.23]
#
# Columna 20:
# Año: nan, Mes: Diciembre, Precio: 30.32
# Fecha construida: 2018-12-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2018-12-01', 30.32]
#
# Columna 21:
# Año: Año 2019, Mes: 2019, Precio: 2019
# Año actual actualizado: 2019
#
# Columna 22:
# Año: nan, Mes: Enero, Precio: 30.81
# Fecha construida: 2019-01-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-01-01', 30.81]
#
# Columna 23:
# Año: nan, Mes: Febrero, Precio: 31.28
# Fecha construida: 2019-02-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-02-01', 31.28]
#
# Columna 24:
# Año: nan, Mes: Marzo, Precio: 31.56
# Fecha construida: 2019-03-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-03-01', 31.56]
#
# Columna 25:
# Año: nan, Mes: Abril, Precio: 31.69
# Fecha construida: 2019-04-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-04-01', 31.69]
#
# Columna 26:
# Año: nan, Mes: Mayo, Precio: 33.15
# Fecha construida: 2019-05-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-05-01', 33.15]
#
# Columna 27:
# Año: nan, Mes: Junio, Precio: 34.3
# Fecha construida: 2019-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-06-01', 34.3]
#
# Columna 28:
# Año: nan, Mes: Julio, Precio: 34.85
# Fecha construida: 2019-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-07-01', 34.85]
#
# Columna 29:
# Año: nan, Mes: Agosto, Precio: 36.04
# Fecha construida: 2019-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-08-01', 36.04]
#
# Columna 30:
# Año: nan, Mes: Septiembre, Precio: 38.34
# Fecha construida: 2019-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-09-01', 38.34]
#
# Columna 31:
# Año: nan, Mes: Octubre, Precio: 38.9
# Fecha construida: 2019-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-10-01', 38.9]
#
# Columna 32:
# Año: nan, Mes: Noviembre, Precio: 39.48
# Fecha construida: 2019-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-11-01', 39.48]
#
# Columna 33:
# Año: nan, Mes: Diciembre, Precio: 40.24
# Fecha construida: 2019-12-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2019-12-01', 40.24]
#
# Columna 34:
# Año: Año 2020, Mes: 2020, Precio: 2020
# Año actual actualizado: 2020
#
# Columna 35:
# Año: nan, Mes: Enero , Precio: 42.07
# Fecha construida: 2020-01-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-01-01', 42.07]
#
# Columna 36:
# Año: nan, Mes: Febrero, Precio: 43.62
# Fecha construida: 2020-02-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-02-01', 43.62]
#
# Columna 37:
# Año: nan, Mes: Marzo, Precio: 43.43
# Fecha construida: 2020-03-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-03-01', 43.43]
#
# Columna 38:
# Año: nan, Mes: Abril, Precio: 43.7
# Fecha construida: 2020-04-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-04-01', 43.7]
#
# Columna 39:
# Año: nan, Mes: Mayo, Precio: 44.22
# Fecha construida: 2020-05-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-05-01', 44.22]
#
# Columna 40:
# Año: nan, Mes: Junio, Precio: 44.41
# Fecha construida: 2020-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-06-01', 44.41]
#
# Columna 41:
# Año: nan, Mes: Julio, Precio: 45.62
# Fecha construida: 2020-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-07-01', 45.62]
#
# Columna 42:
# Año: nan, Mes: Agosto, Precio: 46.04
# Fecha construida: 2020-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-08-01', 46.04]
#
# Columna 43:
# Año: nan, Mes: Septiembre, Precio: 46.12
# Fecha construida: 2020-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-09-01', 46.12]
#
# Columna 44:
# Año: nan, Mes: Octubre, Precio: 47.66
# Fecha construida: 2020-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-10-01', 47.66]
#
# Columna 45:
# Año: nan, Mes: Noviembre, Precio: 45.17
# Fecha construida: 2020-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-11-01', 45.17]
#
# Columna 46:
# Año: nan, Mes: Diciembre, Precio: 42.55
# Fecha construida: 2020-12-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2020-12-01', 42.55]
#
# Columna 47:
# Año: Año 2021, Mes: 2021, Precio: 2021
# Año actual actualizado: 2021
#
# Columna 48:
# Año: nan, Mes: Enero, Precio: 43.62
# Fecha construida: 2021-01-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-01-01', 43.62]
#
# Columna 49:
# Año: nan, Mes: Febrero, Precio: 45.06
# Fecha construida: 2021-02-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-02-01', 45.06]
#
# Columna 50:
# Año: nan, Mes: Marzo, Precio: 45.12
# Fecha construida: 2021-03-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-03-01', 45.12]
#
# Columna 51:
# Año: nan, Mes: Abril, Precio: 46.399629320835
# Fecha construida: 2021-04-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-04-01', 46.399629320835]
#
# Columna 52:
# Año: nan, Mes: Mayo, Precio: 49.5059559771371
# Fecha construida: 2021-05-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-05-01', 49.5059559771371]
#
# Columna 53:
# Año: nan, Mes: Junio, Precio: 50.9380564397098
# Fecha construida: 2021-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-06-01', 50.9380564397098]
#
# Columna 54:
# Año: nan, Mes: Julio, Precio: 52.7091162053103
# Fecha construida: 2021-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-07-01', 52.7091162053103]
#
# Columna 55:
# Año: nan, Mes: Agosto, Precio: 53.547282963772
# Fecha construida: 2021-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-08-01', 53.547282963772]
#
# Columna 56:
# Año: nan, Mes: Septiembre, Precio: 56.83
# Fecha construida: 2021-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-09-01', 56.83]
#
# Columna 57:
# Año: nan, Mes: Octubre, Precio: 59.29
# Fecha construida: 2021-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-10-01', 59.29]
#
# Columna 58:
# Año: nan, Mes: Noviembre, Precio: 59.37
# Fecha construida: 2021-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-11-01', 59.37]
#
# Columna 59:
# Año: nan, Mes: Diciembre, Precio: 59.46
# Fecha construida: 2021-12-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2021-12-01', 59.46]
#
# Columna 60:
# Año: Año 2022, Mes: 2022, Precio: 2022
# Año actual actualizado: 2022
#
# Columna 61:
# Año: nan, Mes: Enero, Precio: 62.82
# Fecha construida: 2022-01-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-01-01', 62.82]
#
# Columna 62:
# Año: nan, Mes: Febrero, Precio: 65.55
# Fecha construida: 2022-02-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-02-01', 65.55]
#
# Columna 63:
# Año: nan, Mes: Marzo, Precio: 74.22
# Fecha construida: 2022-03-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-03-01', 74.22]
#
# Columna 64:
# Año: nan, Mes: Abril, Precio: 86.18
# Fecha construida: 2022-04-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-04-01', 86.18]
#
# Columna 65:
# Año: nan, Mes: Mayo, Precio: 95.25
# Fecha construida: 2022-05-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-05-01', 95.25]
#
# Columna 66:
# Año: nan, Mes: Junio, Precio: 95.24
# Fecha construida: 2022-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-06-01', 95.24]
#
# Columna 67:
# Año: nan, Mes: Julio, Precio: 107.06
# Fecha construida: 2022-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-07-01', 107.06]
#
# Columna 68:
# Año: nan, Mes: Agosto, Precio: 114.41
# Fecha construida: 2022-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-08-01', 114.41]
#
# Columna 69:
# Año: nan, Mes: Septiembre, Precio: 123.46
# Fecha construida: 2022-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-09-01', 123.46]
#
# Columna 70:
# Año: nan, Mes: Octubre, Precio: 132.37
# Fecha construida: 2022-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-10-01', 132.37]
#
# Columna 71:
# Año: nan, Mes: Noviembre, Precio: 140.7
# Fecha construida: 2022-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-11-01', 140.7]
#
# Columna 72:
# Año: nan, Mes: Diciembre, Precio: 146.91
# Fecha construida: 2022-12-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2022-12-01', 146.91]
#
# Columna 73:
# Año: Año 2023, Mes: 2023, Precio: 2023
# Año actual actualizado: 2023
#
# Columna 74:
# Año: nan, Mes: Enero, Precio: 160.14
# Fecha construida: 2023-01-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-01-01', 160.14]
#
# Columna 75:
# Año: nan, Mes: Febrero, Precio: 172.29
# Fecha construida: 2023-02-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-02-01', 172.29]
#
# Columna 76:
# Año: nan, Mes: Marzo, Precio: 176.24
# Fecha construida: 2023-03-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-03-01', 176.24]
#
# Columna 77:
# Año: nan, Mes: Abril, Precio: 185.36
# Fecha construida: 2023-04-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-04-01', 185.36]
#
# Columna 78:
# Año: nan, Mes: Mayo, Precio: 193.13
# Fecha construida: 2023-05-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-05-01', 193.13]
#
# Columna 79:
# Año: nan, Mes: Junio, Precio: 196.65
# Fecha construida: 2023-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-06-01', 196.65]
#
# Columna 80:
# Año: nan, Mes: Julio, Precio: 207.44
# Fecha construida: 2023-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-07-01', 207.44]
#
# Columna 81:
# Año: nan, Mes: Agosto, Precio: 222.91
# Fecha construida: 2023-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-08-01', 222.91]
#
# Columna 82:
# Año: nan, Mes: Septiembre, Precio: 241.22
# Fecha construida: 2023-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-09-01', 241.22]
#
# Columna 83:
# Año: nan, Mes: Octubre, Precio: 269.52
# Fecha construida: 2023-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-10-01', 269.52]
#
# Columna 84:
# Año: nan, Mes: Noviembre, Precio: 323.26
# Fecha construida: 2023-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-11-01', 323.26]
#
# Columna 85:
# Año: nan, Mes: Diciembre, Precio: 492.38
# Fecha construida: 2023-12-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2023-12-01', 492.38]
#
# Columna 86:
# Año: Año 2024, Mes: 2024, Precio: 2024
# Año actual actualizado: 2024
#
# Columna 87:
# Año: nan, Mes: Enero, Precio: 665.79
# Fecha construida: 2024-01-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-01-01', 665.79]
#
# Columna 88:
# Año: nan, Mes: Febrero, Precio: 741.12
# Fecha construida: 2024-02-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-02-01', 741.12]
#
# Columna 89:
# Año: nan, Mes: Marzo, Precio: 818.97
# Fecha construida: 2024-03-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-03-01', 818.97]
#
# Columna 90:
# Año: nan, Mes: Abril, Precio: 816.97
# Fecha construida: 2024-04-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-04-01', 816.97]
#
# Columna 91:
# Año: nan, Mes: Mayo, Precio: 786.85
# Fecha construida: 2024-05-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-05-01', 786.85]
#
# Columna 92:
# Año: nan, Mes: Junio, Precio: 828.26
# Fecha construida: 2024-06-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-06-01', 828.26]
#
# Columna 93:
# Año: nan, Mes: Julio, Precio: 851.77
# Fecha construida: 2024-07-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-07-01', 851.77]
#
# Columna 94:
# Año: nan, Mes: Agosto, Precio: 829.47
# Fecha construida: 2024-08-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-08-01', 829.47]
#
# Columna 95:
# Año: nan, Mes: Septiembre, Precio: 829.22
# Fecha construida: 2024-09-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-09-01', 829.22]
#
# Columna 96:
# Año: nan, Mes: Octubre, Precio: 815.9
# Fecha construida: 2024-10-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-10-01', 815.9]
#
# Columna 97:
# Año: temporal, Mes: Noviembre, Precio: 830.61
# Fecha construida: 2024-11-01
# Fila agregada: ['GBA', 'Harina de trigo común', 'kg', '2024-11-01', 830.61]
#
# fila 3:
# Region: GBA, Producto: Arroz blanco simple, Unidad: kg
#
# Columna 0:
# Año: Año 2017, Mes: 2017, Precio: 2017
# Año actual actualizado: 2017
#
# Columna 1:
# Año: nan, Mes: Junio, Precio: 20.96
# Fecha construida: 2017-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2017-06-01', 20.96]
#
# Columna 2:
# Año: nan, Mes: Julio, Precio: 21.08
# Fecha construida: 2017-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2017-07-01', 21.08]
#
# Columna 3:
# Año: nan, Mes: Agosto, Precio: 21.25
# Fecha construida: 2017-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2017-08-01', 21.25]
#
# Columna 4:
# Año: nan, Mes: Septiembre, Precio: 21.49
# Fecha construida: 2017-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2017-09-01', 21.49]
#
# Columna 5:
# Año: nan, Mes: Octubre, Precio: 21.74
# Fecha construida: 2017-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2017-10-01', 21.74]
#
# Columna 6:
# Año: nan, Mes: Noviembre, Precio: 21.74
# Fecha construida: 2017-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2017-11-01', 21.74]
#
# Columna 7:
# Año: nan, Mes: Diciembre, Precio: 22.1
# Fecha construida: 2017-12-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2017-12-01', 22.1]
#
# Columna 8:
# Año: Año 2018, Mes: 2018, Precio: 2018
# Año actual actualizado: 2018
#
# Columna 9:
# Año: nan, Mes: Enero, Precio: 22.81
# Fecha construida: 2018-01-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-01-01', 22.81]
#
# Columna 10:
# Año: nan, Mes: Febrero, Precio: 23.22
# Fecha construida: 2018-02-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-02-01', 23.22]
#
# Columna 11:
# Año: nan, Mes: Marzo, Precio: 23.84
# Fecha construida: 2018-03-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-03-01', 23.84]
#
# Columna 12:
# Año: nan, Mes: Abril, Precio: 24.37
# Fecha construida: 2018-04-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-04-01', 24.37]
#
# Columna 13:
# Año: nan, Mes: Mayo, Precio: 24.64
# Fecha construida: 2018-05-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-05-01', 24.64]
#
# Columna 14:
# Año: nan, Mes: Junio, Precio: 25.99
# Fecha construida: 2018-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-06-01', 25.99]
#
# Columna 15:
# Año: nan, Mes: Julio, Precio: 26.82
# Fecha construida: 2018-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-07-01', 26.82]
#
# Columna 16:
# Año: nan, Mes: Agosto, Precio: 28.7
# Fecha construida: 2018-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-08-01', 28.7]
#
# Columna 17:
# Año: nan, Mes: Septiembre, Precio: 33.39
# Fecha construida: 2018-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-09-01', 33.39]
#
# Columna 18:
# Año: nan, Mes: Octubre, Precio: 35.53
# Fecha construida: 2018-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-10-01', 35.53]
#
# Columna 19:
# Año: nan, Mes: Noviembre, Precio: 37.65
# Fecha construida: 2018-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-11-01', 37.65]
#
# Columna 20:
# Año: nan, Mes: Diciembre, Precio: 38.61
# Fecha construida: 2018-12-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2018-12-01', 38.61]
#
# Columna 21:
# Año: Año 2019, Mes: 2019, Precio: 2019
# Año actual actualizado: 2019
#
# Columna 22:
# Año: nan, Mes: Enero, Precio: 39.39
# Fecha construida: 2019-01-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-01-01', 39.39]
#
# Columna 23:
# Año: nan, Mes: Febrero, Precio: 40.6
# Fecha construida: 2019-02-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-02-01', 40.6]
#
# Columna 24:
# Año: nan, Mes: Marzo, Precio: 40.94
# Fecha construida: 2019-03-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-03-01', 40.94]
#
# Columna 25:
# Año: nan, Mes: Abril, Precio: 42.2
# Fecha construida: 2019-04-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-04-01', 42.2]
#
# Columna 26:
# Año: nan, Mes: Mayo, Precio: 44.27
# Fecha construida: 2019-05-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-05-01', 44.27]
#
# Columna 27:
# Año: nan, Mes: Junio, Precio: 45.36
# Fecha construida: 2019-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-06-01', 45.36]
#
# Columna 28:
# Año: nan, Mes: Julio, Precio: 45.83
# Fecha construida: 2019-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-07-01', 45.83]
#
# Columna 29:
# Año: nan, Mes: Agosto, Precio: 48.48
# Fecha construida: 2019-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-08-01', 48.48]
#
# Columna 30:
# Año: nan, Mes: Septiembre, Precio: 49.5
# Fecha construida: 2019-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-09-01', 49.5]
#
# Columna 31:
# Año: nan, Mes: Octubre, Precio: 50.38
# Fecha construida: 2019-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-10-01', 50.38]
#
# Columna 32:
# Año: nan, Mes: Noviembre, Precio: 54.75
# Fecha construida: 2019-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-11-01', 54.75]
#
# Columna 33:
# Año: nan, Mes: Diciembre, Precio: 57.46
# Fecha construida: 2019-12-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2019-12-01', 57.46]
#
# Columna 34:
# Año: Año 2020, Mes: 2020, Precio: 2020
# Año actual actualizado: 2020
#
# Columna 35:
# Año: nan, Mes: Enero , Precio: 63.84
# Fecha construida: 2020-01-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-01-01', 63.84]
#
# Columna 36:
# Año: nan, Mes: Febrero, Precio: 66.04
# Fecha construida: 2020-02-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-02-01', 66.04]
#
# Columna 37:
# Año: nan, Mes: Marzo, Precio: 67.75
# Fecha construida: 2020-03-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-03-01', 67.75]
#
# Columna 38:
# Año: nan, Mes: Abril, Precio: 70.13
# Fecha construida: 2020-04-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-04-01', 70.13]
#
# Columna 39:
# Año: nan, Mes: Mayo, Precio: 70.22
# Fecha construida: 2020-05-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-05-01', 70.22]
#
# Columna 40:
# Año: nan, Mes: Junio, Precio: 72.56
# Fecha construida: 2020-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-06-01', 72.56]
#
# Columna 41:
# Año: nan, Mes: Julio, Precio: 73.25
# Fecha construida: 2020-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-07-01', 73.25]
#
# Columna 42:
# Año: nan, Mes: Agosto, Precio: 73.8
# Fecha construida: 2020-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-08-01', 73.8]
#
# Columna 43:
# Año: nan, Mes: Septiembre, Precio: 75.75
# Fecha construida: 2020-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-09-01', 75.75]
#
# Columna 44:
# Año: nan, Mes: Octubre, Precio: 80.55
# Fecha construida: 2020-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-10-01', 80.55]
#
# Columna 45:
# Año: nan, Mes: Noviembre, Precio: 80.9
# Fecha construida: 2020-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-11-01', 80.9]
#
# Columna 46:
# Año: nan, Mes: Diciembre, Precio: 81.76
# Fecha construida: 2020-12-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2020-12-01', 81.76]
#
# Columna 47:
# Año: Año 2021, Mes: 2021, Precio: 2021
# Año actual actualizado: 2021
#
# Columna 48:
# Año: nan, Mes: Enero, Precio: 81.53
# Fecha construida: 2021-01-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-01-01', 81.53]
#
# Columna 49:
# Año: nan, Mes: Febrero, Precio: 81.61
# Fecha construida: 2021-02-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-02-01', 81.61]
#
# Columna 50:
# Año: nan, Mes: Marzo, Precio: 84.36
# Fecha construida: 2021-03-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-03-01', 84.36]
#
# Columna 51:
# Año: nan, Mes: Abril, Precio: 96.383823096717
# Fecha construida: 2021-04-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-04-01', 96.383823096717]
#
# Columna 52:
# Año: nan, Mes: Mayo, Precio: 108.970152781559
# Fecha construida: 2021-05-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-05-01', 108.970152781559]
#
# Columna 53:
# Año: nan, Mes: Junio, Precio: 111.682709382476
# Fecha construida: 2021-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-06-01', 111.682709382476]
#
# Columna 54:
# Año: nan, Mes: Julio, Precio: 111.743490566369
# Fecha construida: 2021-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-07-01', 111.743490566369]
#
# Columna 55:
# Año: nan, Mes: Agosto, Precio: 117.360671749081
# Fecha construida: 2021-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-08-01', 117.360671749081]
#
# Columna 56:
# Año: nan, Mes: Septiembre, Precio: 115.14
# Fecha construida: 2021-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-09-01', 115.14]
#
# Columna 57:
# Año: nan, Mes: Octubre, Precio: 116.74
# Fecha construida: 2021-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-10-01', 116.74]
#
# Columna 58:
# Año: nan, Mes: Noviembre, Precio: 114.43
# Fecha construida: 2021-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-11-01', 114.43]
#
# Columna 59:
# Año: nan, Mes: Diciembre, Precio: 114.82
# Fecha construida: 2021-12-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2021-12-01', 114.82]
#
# Columna 60:
# Año: Año 2022, Mes: 2022, Precio: 2022
# Año actual actualizado: 2022
#
# Columna 61:
# Año: nan, Mes: Enero, Precio: 120.6
# Fecha construida: 2022-01-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-01-01', 120.6]
#
# Columna 62:
# Año: nan, Mes: Febrero, Precio: 120.62
# Fecha construida: 2022-02-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-02-01', 120.62]
#
# Columna 63:
# Año: nan, Mes: Marzo, Precio: 124.5
# Fecha construida: 2022-03-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-03-01', 124.5]
#
# Columna 64:
# Año: nan, Mes: Abril, Precio: 127.08
# Fecha construida: 2022-04-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-04-01', 127.08]
#
# Columna 65:
# Año: nan, Mes: Mayo, Precio: 131.18
# Fecha construida: 2022-05-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-05-01', 131.18]
#
# Columna 66:
# Año: nan, Mes: Junio, Precio: 136.95
# Fecha construida: 2022-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-06-01', 136.95]
#
# Columna 67:
# Año: nan, Mes: Julio, Precio: 137.75
# Fecha construida: 2022-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-07-01', 137.75]
#
# Columna 68:
# Año: nan, Mes: Agosto, Precio: 143.83
# Fecha construida: 2022-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-08-01', 143.83]
#
# Columna 69:
# Año: nan, Mes: Septiembre, Precio: 154.33
# Fecha construida: 2022-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-09-01', 154.33]
#
# Columna 70:
# Año: nan, Mes: Octubre, Precio: 167.76
# Fecha construida: 2022-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-10-01', 167.76]
#
# Columna 71:
# Año: nan, Mes: Noviembre, Precio: 173.27
# Fecha construida: 2022-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-11-01', 173.27]
#
# Columna 72:
# Año: nan, Mes: Diciembre, Precio: 183.52
# Fecha construida: 2022-12-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2022-12-01', 183.52]
#
# Columna 73:
# Año: Año 2023, Mes: 2023, Precio: 2023
# Año actual actualizado: 2023
#
# Columna 74:
# Año: nan, Mes: Enero, Precio: 198.02
# Fecha construida: 2023-01-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-01-01', 198.02]
#
# Columna 75:
# Año: nan, Mes: Febrero, Precio: 226.87
# Fecha construida: 2023-02-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-02-01', 226.87]
#
# Columna 76:
# Año: nan, Mes: Marzo, Precio: 242.47
# Fecha construida: 2023-03-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-03-01', 242.47]
#
# Columna 77:
# Año: nan, Mes: Abril, Precio: 269.86
# Fecha construida: 2023-04-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-04-01', 269.86]
#
# Columna 78:
# Año: nan, Mes: Mayo, Precio: 318.44
# Fecha construida: 2023-05-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-05-01', 318.44]
#
# Columna 79:
# Año: nan, Mes: Junio, Precio: 358.85
# Fecha construida: 2023-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-06-01', 358.85]
#
# Columna 80:
# Año: nan, Mes: Julio, Precio: 403.18
# Fecha construida: 2023-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-07-01', 403.18]
#
# Columna 81:
# Año: nan, Mes: Agosto, Precio: 460.4
# Fecha construida: 2023-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-08-01', 460.4]
#
# Columna 82:
# Año: nan, Mes: Septiembre, Precio: 582.04
# Fecha construida: 2023-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-09-01', 582.04]
#
# Columna 83:
# Año: nan, Mes: Octubre, Precio: 789.18
# Fecha construida: 2023-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-10-01', 789.18]
#
# Columna 84:
# Año: nan, Mes: Noviembre, Precio: 1020.69
# Fecha construida: 2023-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-11-01', 1020.69]
#
# Columna 85:
# Año: nan, Mes: Diciembre, Precio: 1557.53
# Fecha construida: 2023-12-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2023-12-01', 1557.53]
#
# Columna 86:
# Año: Año 2024, Mes: 2024, Precio: 2024
# Año actual actualizado: 2024
#
# Columna 87:
# Año: nan, Mes: Enero, Precio: 2046.61
# Fecha construida: 2024-01-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-01-01', 2046.61]
#
# Columna 88:
# Año: nan, Mes: Febrero, Precio: 2355.31
# Fecha construida: 2024-02-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-02-01', 2355.31]
#
# Columna 89:
# Año: nan, Mes: Marzo, Precio: 2445.35
# Fecha construida: 2024-03-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-03-01', 2445.35]
#
# Columna 90:
# Año: nan, Mes: Abril, Precio: 2422.83
# Fecha construida: 2024-04-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-04-01', 2422.83]
#
# Columna 91:
# Año: nan, Mes: Mayo, Precio: 2351.11
# Fecha construida: 2024-05-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-05-01', 2351.11]
#
# Columna 92:
# Año: nan, Mes: Junio, Precio: 2336.91
# Fecha construida: 2024-06-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-06-01', 2336.91]
#
# Columna 93:
# Año: nan, Mes: Julio, Precio: 2301.88
# Fecha construida: 2024-07-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-07-01', 2301.88]
#
# Columna 94:
# Año: nan, Mes: Agosto, Precio: 2288.26
# Fecha construida: 2024-08-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-08-01', 2288.26]
#
# Columna 95:
# Año: nan, Mes: Septiembre, Precio: 2262
# Fecha construida: 2024-09-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-09-01', 2262]
#
# Columna 96:
# Año: nan, Mes: Octubre, Precio: 2285.88
# Fecha construida: 2024-10-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-10-01', 2285.88]
#
# Columna 97:
# Año: temporal, Mes: Noviembre, Precio: 2273.69
# Fecha construida: 2024-11-01
# Fila agregada: ['GBA', 'Arroz blanco simple', 'kg', '2024-11-01', 2273.69]
#
# fila 4:
# Region: GBA, Producto: Fideos secos tipo guisero, Unidad: 500 g
#
# Columna 0:
# Año: Año 2017, Mes: 2017, Precio: 2017
# Año actual actualizado: 2017
#
# Columna 1:
# Año: nan, Mes: Junio, Precio: 19.08
# Fecha construida: 2017-06-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2017-06-01', 19.08]
#
# Columna 2:
# Año: nan, Mes: Julio, Precio: 19.53
# Fecha construida: 2017-07-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2017-07-01', 19.53]
#
# Columna 3:
# Año: nan, Mes: Agosto, Precio: 19.73
# Fecha construida: 2017-08-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2017-08-01', 19.73]
#
# Columna 4:
# Año: nan, Mes: Septiembre, Precio: 19.86
# Fecha construida: 2017-09-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2017-09-01', 19.86]
#
# Columna 5:
# Año: nan, Mes: Octubre, Precio: 20.13
# Fecha construida: 2017-10-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2017-10-01', 20.13]
#
# Columna 6:
# Año: nan, Mes: Noviembre, Precio: 20.34
# Fecha construida: 2017-11-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2017-11-01', 20.34]
#
# Columna 7:
# Año: nan, Mes: Diciembre, Precio: 20.54
# Fecha construida: 2017-12-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2017-12-01', 20.54]
#
# Columna 8:
# Año: Año 2018, Mes: 2018, Precio: 2018
# Año actual actualizado: 2018
#
# Columna 9:
# Año: nan, Mes: Enero, Precio: 21.23
# Fecha construida: 2018-01-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-01-01', 21.23]
#
# Columna 10:
# Año: nan, Mes: Febrero, Precio: 21.56
# Fecha construida: 2018-02-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-02-01', 21.56]
#
# Columna 11:
# Año: nan, Mes: Marzo, Precio: 22.35
# Fecha construida: 2018-03-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-03-01', 22.35]
#
# Columna 12:
# Año: nan, Mes: Abril, Precio: 22.86
# Fecha construida: 2018-04-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-04-01', 22.86]
#
# Columna 13:
# Año: nan, Mes: Mayo, Precio: 25.03
# Fecha construida: 2018-05-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-05-01', 25.03]
#
# Columna 14:
# Año: nan, Mes: Junio, Precio: 26.94
# Fecha construida: 2018-06-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-06-01', 26.94]
#
# Columna 15:
# Año: nan, Mes: Julio, Precio: 28.33
# Fecha construida: 2018-07-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-07-01', 28.33]
#
# Columna 16:
# Año: nan, Mes: Agosto, Precio: 28.88
# Fecha construida: 2018-08-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-08-01', 28.88]
#
# Columna 17:
# Año: nan, Mes: Septiembre, Precio: 34.68
# Fecha construida: 2018-09-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-09-01', 34.68]
#
# Columna 18:
# Año: nan, Mes: Octubre, Precio: 37.81
# Fecha construida: 2018-10-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-10-01', 37.81]
#
# Columna 19:
# Año: nan, Mes: Noviembre, Precio: 40.34
# Fecha construida: 2018-11-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-11-01', 40.34]
#
# Columna 20:
# Año: nan, Mes: Diciembre, Precio: 41.28
# Fecha construida: 2018-12-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2018-12-01', 41.28]
#
# Columna 21:
# Año: Año 2019, Mes: 2019, Precio: 2019
# Año actual actualizado: 2019
#
# Columna 22:
# Año: nan, Mes: Enero, Precio: 42.15
# Fecha construida: 2019-01-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-01-01', 42.15]
#
# Columna 23:
# Año: nan, Mes: Febrero, Precio: 43.21
# Fecha construida: 2019-02-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-02-01', 43.21]
#
# Columna 24:
# Año: nan, Mes: Marzo, Precio: 43.89
# Fecha construida: 2019-03-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-03-01', 43.89]
#
# Columna 25:
# Año: nan, Mes: Abril, Precio: 46.99
# Fecha construida: 2019-04-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-04-01', 46.99]
#
# Columna 26:
# Año: nan, Mes: Mayo, Precio: 48.3
# Fecha construida: 2019-05-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-05-01', 48.3]
#
# Columna 27:
# Año: nan, Mes: Junio, Precio: 48.47
# Fecha construida: 2019-06-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-06-01', 48.47]
#
# Columna 28:
# Año: nan, Mes: Julio, Precio: 49.29
# Fecha construida: 2019-07-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-07-01', 49.29]
#
# Columna 29:
# Año: nan, Mes: Agosto, Precio: 49.95
# Fecha construida: 2019-08-01
# Fila agregada: ['GBA', 'Fideos secos tipo guisero', '500 g', '2019-08-01', 49.95]
#
# Columna 30:
# ...
# Fila agregada: ['Patagonia', 'Lavandina', '1.000 cc', '2024-06-01', 1088.59]
#
# Columna 93:
# Año: nan, Mes: Julio, Precio: 1162.98
# Fecha construida: 2024-07-01
# Fila agregada: ['Patagonia', 'Lavandina', '1.000 cc', '2024-07-01', 1162.98]
#
# Columna 94:
# Año: nan, Mes: Agosto, Precio: 1206.88
# Fecha construida: 2024-08-01
# Fila agregada: ['Patagonia', 'Lavandina', '1.000 cc', '2024-08-01', 1206.88]
#
# Columna 95:
# Año: nan, Mes: Septiembre, Precio: 1216.43
# Fecha construida: 2024-09-01
# Fila agregada: ['Patagonia', 'Lavandina', '1.000 cc', '2024-09-01', 1216.43]
#
# Columna 96:
# Año: nan, Mes: Octubre, Precio: 1229.42
# Fecha construida: 2024-10-01
# Fila agregada: ['Patagonia', 'Lavandina', '1.000 cc', '2024-10-01', 1229.42]
#
# Columna 97:
# Año: temporal, Mes: Noviembre, Precio: 1228.51
# Fecha construida: 2024-11-01
# Fila agregada: ['Patagonia', 'Lavandina', '1.000 cc', '2024-11-01', 1228.51]
#
# fila 84:
# Region: Patagonia, Producto: Jabón de tocador, Unidad: 125 g
#
# Columna 0:
# Año: Año 2017, Mes: 2017, Precio: 2017
# Año actual actualizado: 2017
#
# Columna 1:
# Año: nan, Mes: Junio, Precio: 15.09
# Fecha construida: 2017-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2017-06-01', 15.09]
#
# Columna 2:
# Año: nan, Mes: Julio, Precio: 15.3
# Fecha construida: 2017-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2017-07-01', 15.3]
#
# Columna 3:
# Año: nan, Mes: Agosto, Precio: 15.6
# Fecha construida: 2017-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2017-08-01', 15.6]
#
# Columna 4:
# Año: nan, Mes: Septiembre, Precio: 15.58
# Fecha construida: 2017-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2017-09-01', 15.58]
#
# Columna 5:
# Año: nan, Mes: Octubre, Precio: 15.68
# Fecha construida: 2017-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2017-10-01', 15.68]
#
# Columna 6:
# Año: nan, Mes: Noviembre, Precio: 15.58
# Fecha construida: 2017-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2017-11-01', 15.58]
#
# Columna 7:
# Año: nan, Mes: Diciembre, Precio: 15.74
# Fecha construida: 2017-12-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2017-12-01', 15.74]
#
# Columna 8:
# Año: Año 2018, Mes: 2018, Precio: 2018
# Año actual actualizado: 2018
#
# Columna 9:
# Año: nan, Mes: Enero, Precio: 15.89
# Fecha construida: 2018-01-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-01-01', 15.89]
#
# Columna 10:
# Año: nan, Mes: Febrero, Precio: 16.19
# Fecha construida: 2018-02-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-02-01', 16.19]
#
# Columna 11:
# Año: nan, Mes: Marzo, Precio: 16.51
# Fecha construida: 2018-03-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-03-01', 16.51]
#
# Columna 12:
# Año: nan, Mes: Abril, Precio: 16.79
# Fecha construida: 2018-04-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-04-01', 16.79]
#
# Columna 13:
# Año: nan, Mes: Mayo, Precio: 16.91
# Fecha construida: 2018-05-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-05-01', 16.91]
#
# Columna 14:
# Año: nan, Mes: Junio, Precio: 18.25
# Fecha construida: 2018-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-06-01', 18.25]
#
# Columna 15:
# Año: nan, Mes: Julio, Precio: 19
# Fecha construida: 2018-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-07-01', 19]
#
# Columna 16:
# Año: nan, Mes: Agosto, Precio: 20.01
# Fecha construida: 2018-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-08-01', 20.01]
#
# Columna 17:
# Año: nan, Mes: Septiembre, Precio: 21.86
# Fecha construida: 2018-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-09-01', 21.86]
#
# Columna 18:
# Año: nan, Mes: Octubre, Precio: 23.66
# Fecha construida: 2018-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-10-01', 23.66]
#
# Columna 19:
# Año: nan, Mes: Noviembre, Precio: 24.75
# Fecha construida: 2018-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-11-01', 24.75]
#
# Columna 20:
# Año: nan, Mes: Diciembre, Precio: 24.98
# Fecha construida: 2018-12-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2018-12-01', 24.98]
#
# Columna 21:
# Año: Año 2019, Mes: 2019, Precio: 2019
# Año actual actualizado: 2019
#
# Columna 22:
# Año: nan, Mes: Enero, Precio: 26.86
# Fecha construida: 2019-01-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-01-01', 26.86]
#
# Columna 23:
# Año: nan, Mes: Febrero, Precio: 28.41
# Fecha construida: 2019-02-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-02-01', 28.41]
#
# Columna 24:
# Año: nan, Mes: Marzo, Precio: 29.05
# Fecha construida: 2019-03-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-03-01', 29.05]
#
# Columna 25:
# Año: nan, Mes: Abril, Precio: 30.01
# Fecha construida: 2019-04-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-04-01', 30.01]
#
# Columna 26:
# Año: nan, Mes: Mayo, Precio: 31.41
# Fecha construida: 2019-05-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-05-01', 31.41]
#
# Columna 27:
# Año: nan, Mes: Junio, Precio: 31.97
# Fecha construida: 2019-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-06-01', 31.97]
#
# Columna 28:
# Año: nan, Mes: Julio, Precio: 32.8
# Fecha construida: 2019-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-07-01', 32.8]
#
# Columna 29:
# Año: nan, Mes: Agosto, Precio: 34.76
# Fecha construida: 2019-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-08-01', 34.76]
#
# Columna 30:
# Año: nan, Mes: Septiembre, Precio: 37.11
# Fecha construida: 2019-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-09-01', 37.11]
#
# Columna 31:
# Año: nan, Mes: Octubre, Precio: 39.02
# Fecha construida: 2019-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-10-01', 39.02]
#
# Columna 32:
# Año: nan, Mes: Noviembre, Precio: 42.42
# Fecha construida: 2019-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-11-01', 42.42]
#
# Columna 33:
# Año: nan, Mes: Diciembre, Precio: 44.58
# Fecha construida: 2019-12-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2019-12-01', 44.58]
#
# Columna 34:
# Año: Año 2020, Mes: 2020, Precio: 2020
# Año actual actualizado: 2020
#
# Columna 35:
# Año: nan, Mes: Enero , Precio: 46.27
# Fecha construida: 2020-01-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-01-01', 46.27]
#
# Columna 36:
# Año: nan, Mes: Febrero, Precio: 47.18
# Fecha construida: 2020-02-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-02-01', 47.18]
#
# Columna 37:
# Año: nan, Mes: Marzo, Precio: ///
# Fecha construida: 2020-03-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-03-01', '///']
#
# Columna 38:
# Año: nan, Mes: Abril, Precio: 46.59
# Fecha construida: 2020-04-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-04-01', 46.59]
#
# Columna 39:
# Año: nan, Mes: Mayo, Precio: 48.8
# Fecha construida: 2020-05-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-05-01', 48.8]
#
# Columna 40:
# Año: nan, Mes: Junio, Precio: 48.4
# Fecha construida: 2020-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-06-01', 48.4]
#
# Columna 41:
# Año: nan, Mes: Julio, Precio: 49
# Fecha construida: 2020-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-07-01', 49]
#
# Columna 42:
# Año: nan, Mes: Agosto, Precio: 49.96
# Fecha construida: 2020-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-08-01', 49.96]
#
# Columna 43:
# Año: nan, Mes: Septiembre, Precio: 50.5
# Fecha construida: 2020-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-09-01', 50.5]
#
# Columna 44:
# Año: nan, Mes: Octubre, Precio: 50.96
# Fecha construida: 2020-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-10-01', 50.96]
#
# Columna 45:
# Año: nan, Mes: Noviembre, Precio: 52.58
# Fecha construida: 2020-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-11-01', 52.58]
#
# Columna 46:
# Año: nan, Mes: Diciembre, Precio: 52.88
# Fecha construida: 2020-12-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2020-12-01', 52.88]
#
# Columna 47:
# Año: Año 2021, Mes: 2021, Precio: 2021
# Año actual actualizado: 2021
#
# Columna 48:
# Año: nan, Mes: Enero, Precio: 54.18
# Fecha construida: 2021-01-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-01-01', 54.18]
#
# Columna 49:
# Año: nan, Mes: Febrero, Precio: 54.11
# Fecha construida: 2021-02-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-02-01', 54.11]
#
# Columna 50:
# Año: nan, Mes: Marzo, Precio: 54.29
# Fecha construida: 2021-03-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-03-01', 54.29]
#
# Columna 51:
# Año: nan, Mes: Abril, Precio: 54.5110062698816
# Fecha construida: 2021-04-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-04-01', 54.5110062698816]
#
# Columna 52:
# Año: nan, Mes: Mayo, Precio: 56.11086248
# Fecha construida: 2021-05-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-05-01', 56.11086248]
#
# Columna 53:
# Año: nan, Mes: Junio, Precio: 58.0556798985019
# Fecha construida: 2021-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-06-01', 58.0556798985019]
#
# Columna 54:
# Año: nan, Mes: Julio, Precio: 60.3660441552043
# Fecha construida: 2021-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-07-01', 60.3660441552043]
#
# Columna 55:
# Año: nan, Mes: Agosto, Precio: 61.94398303
# Fecha construida: 2021-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-08-01', 61.94398303]
#
# Columna 56:
# Año: nan, Mes: Septiembre, Precio: 63.97
# Fecha construida: 2021-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-09-01', 63.97]
#
# Columna 57:
# Año: nan, Mes: Octubre, Precio: 64.91
# Fecha construida: 2021-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-10-01', 64.91]
#
# Columna 58:
# Año: nan, Mes: Noviembre, Precio: 67.5
# Fecha construida: 2021-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-11-01', 67.5]
#
# Columna 59:
# Año: nan, Mes: Diciembre, Precio: 70.33
# Fecha construida: 2021-12-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2021-12-01', 70.33]
#
# Columna 60:
# Año: Año 2022, Mes: 2022, Precio: 2022
# Año actual actualizado: 2022
#
# Columna 61:
# Año: nan, Mes: Enero, Precio: 73.82
# Fecha construida: 2022-01-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-01-01', 73.82]
#
# Columna 62:
# Año: nan, Mes: Febrero, Precio: 79.87
# Fecha construida: 2022-02-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-02-01', 79.87]
#
# Columna 63:
# Año: nan, Mes: Marzo, Precio: 87.15
# Fecha construida: 2022-03-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-03-01', 87.15]
#
# Columna 64:
# Año: nan, Mes: Abril, Precio: 90.81
# Fecha construida: 2022-04-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-04-01', 90.81]
#
# Columna 65:
# Año: nan, Mes: Mayo, Precio: 97.02
# Fecha construida: 2022-05-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-05-01', 97.02]
#
# Columna 66:
# Año: nan, Mes: Junio, Precio: 103.8
# Fecha construida: 2022-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-06-01', 103.8]
#
# Columna 67:
# Año: nan, Mes: Julio, Precio: 115.81
# Fecha construida: 2022-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-07-01', 115.81]
#
# Columna 68:
# Año: nan, Mes: Agosto, Precio: 129.03
# Fecha construida: 2022-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-08-01', 129.03]
#
# Columna 69:
# Año: nan, Mes: Septiembre, Precio: 142.68
# Fecha construida: 2022-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-09-01', 142.68]
#
# Columna 70:
# Año: nan, Mes: Octubre, Precio: 156.12
# Fecha construida: 2022-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-10-01', 156.12]
#
# Columna 71:
# Año: nan, Mes: Noviembre, Precio: 165.94
# Fecha construida: 2022-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-11-01', 165.94]
#
# Columna 72:
# Año: nan, Mes: Diciembre, Precio: 176.19
# Fecha construida: 2022-12-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2022-12-01', 176.19]
#
# Columna 73:
# Año: Año 2023, Mes: 2023, Precio: 2023
# Año actual actualizado: 2023
#
# Columna 74:
# Año: nan, Mes: Enero, Precio: 190.05
# Fecha construida: 2023-01-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-01-01', 190.05]
#
# Columna 75:
# Año: nan, Mes: Febrero, Precio: 200.22
# Fecha construida: 2023-02-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-02-01', 200.22]
#
# Columna 76:
# Año: nan, Mes: Marzo, Precio: 205.2
# Fecha construida: 2023-03-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-03-01', 205.2]
#
# Columna 77:
# Año: nan, Mes: Abril, Precio: 218.15
# Fecha construida: 2023-04-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-04-01', 218.15]
#
# Columna 78:
# Año: nan, Mes: Mayo, Precio: 229.81
# Fecha construida: 2023-05-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-05-01', 229.81]
#
# Columna 79:
# Año: nan, Mes: Junio, Precio: 241.43
# Fecha construida: 2023-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-06-01', 241.43]
#
# Columna 80:
# Año: nan, Mes: Julio, Precio: 255.59
# Fecha construida: 2023-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-07-01', 255.59]
#
# Columna 81:
# Año: nan, Mes: Agosto, Precio: 278.89
# Fecha construida: 2023-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-08-01', 278.89]
#
# Columna 82:
# Año: nan, Mes: Septiembre, Precio: 304.66
# Fecha construida: 2023-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-09-01', 304.66]
#
# Columna 83:
# Año: nan, Mes: Octubre, Precio: 320.42
# Fecha construida: 2023-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-10-01', 320.42]
#
# Columna 84:
# Año: nan, Mes: Noviembre, Precio: 347.99
# Fecha construida: 2023-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-11-01', 347.99]
#
# Columna 85:
# Año: nan, Mes: Diciembre, Precio: 475.26
# Fecha construida: 2023-12-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2023-12-01', 475.26]
#
# Columna 86:
# Año: Año 2024, Mes: 2024, Precio: 2024
# Año actual actualizado: 2024
#
# Columna 87:
# Año: nan, Mes: Enero, Precio: 714.94
# Fecha construida: 2024-01-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-01-01', 714.94]
#
# Columna 88:
# Año: nan, Mes: Febrero, Precio: 817.54
# Fecha construida: 2024-02-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-02-01', 817.54]
#
# Columna 89:
# Año: nan, Mes: Marzo, Precio: 844.65
# Fecha construida: 2024-03-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-03-01', 844.65]
#
# Columna 90:
# Año: nan, Mes: Abril, Precio: 880.49
# Fecha construida: 2024-04-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-04-01', 880.49]
#
# Columna 91:
# Año: nan, Mes: Mayo, Precio: 913.33
# Fecha construida: 2024-05-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-05-01', 913.33]
#
# Columna 92:
# Año: nan, Mes: Junio, Precio: 909.57
# Fecha construida: 2024-06-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-06-01', 909.57]
#
# Columna 93:
# Año: nan, Mes: Julio, Precio: 904.17
# Fecha construida: 2024-07-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-07-01', 904.17]
#
# Columna 94:
# Año: nan, Mes: Agosto, Precio: 915.87
# Fecha construida: 2024-08-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-08-01', 915.87]
#
# Columna 95:
# Año: nan, Mes: Septiembre, Precio: 957.23
# Fecha construida: 2024-09-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-09-01', 957.23]
#
# Columna 96:
# Año: nan, Mes: Octubre, Precio: 998.82
# Fecha construida: 2024-10-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-10-01', 998.82]
#
# Columna 97:
# Año: temporal, Mes: Noviembre, Precio: 1011.4
# Fecha construida: 2024-11-01
# Fila agregada: ['Patagonia', 'Jabón de tocador', '125 g', '2024-11-01', 1011.4]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     7560 non-null   object
#  1   Region   7560 non-null   object
#  2   Product  7560 non-null   object
#  3   Unit     7560 non-null   object
#  4   Price    7560 non-null   object
# dtypes: object(5)
# memory usage: 295.4+ KB

# %% [markdown]
# ### Validaciones y control de errores.

# %%
region_u = final_df['Region'].unique()
region_u
# Valores Correctos.
# Out:
# array(['GBA', 'Pampeana', 'Noreste', 'Noroeste', 'Cuyo', 'Patagonia'],
#       dtype=object)

# %%
product_u = final_df['Product'].unique()
product_u
# Valores Correctos.
# Out:
# array(['Pan francés', 'Harina de trigo común', 'Arroz blanco simple',
#        'Fideos secos tipo guisero', 'Carne picada común', 'Pollo entero',
#        'Aceite de girasol', 'Leche fresca entera sachet',
#        'Huevos de gallina', 'Papa', 'Azúcar', 'Detergente líquido',
#        'Lavandina', 'Jabón de tocador'], dtype=object)

# %%
unit_u = final_df['Unit'].unique()
unit_u
# Valores Correctos.
# Out:
# array(['kg', '500 g', '1,5 litros', 'Litro', 'Docena', '750 cc',
#        '1.000 cc', '125 g'], dtype=object)

# %%
# Convertir la columna "Price" a numérica, forzando los errores a NaN
final_df["Price"] = pd.to_numeric(final_df["Price"], errors="coerce")

# Mostrar las filas con valores faltantes
missing_values = final_df[final_df["Price"].isna()]
missing_values
# Out:
#             Date     Region                     Product      Unit  Price
# 6693  2020-03-01  Patagonia          Carne picada común        kg    NaN
# 6963  2020-03-01  Patagonia  Leche fresca entera sachet     Litro    NaN
# 7053  2020-03-01  Patagonia           Huevos de gallina    Docena    NaN
# 7323  2020-03-01  Patagonia          Detergente líquido    750 cc    NaN
# 7413  2020-03-01  Patagonia                   Lavandina  1.000 cc    NaN
# 7503  2020-03-01  Patagonia            Jabón de tocador     125 g    NaN

# %% [markdown]
# ### Podemos identificar que los errores estan en Marzo de 2020. en solo algunos productos, vamos a sacar la adyacente de los meses anteriores y subsiguientes para rellenar con valores cercanos de esos productos y regiones continuando la tendencia de los datos.

# %%
def fill_missing_with_adjacent(df):
    # Ordenar el DataFrame por "Date" para asegurar que los datos estén en orden cronológico
    df = df.sort_values(by="Date")
    
    # Iterar sobre cada fila con valores faltantes
    for index, row in df[df["Price"].isna()].iterrows():
        region = row["Region"]
        product = row["Product"]
        unit = row["Unit"]
        date = row["Date"]
        
        # Filtrar el DataFrame para obtener solo los datos del mismo producto y región
        product_data = df[(df["Region"] == region) & (df["Product"] == product) & (df["Unit"] == unit)]
        
        # Obtener los precios del mes anterior y el mes siguiente
        previous_price = product_data[product_data["Date"] < date]["Price"].dropna().tail(1)
        next_price = product_data[product_data["Date"] > date]["Price"].dropna().head(1)
        
        # Calcular el promedio de los valores disponibles
        if not previous_price.empty and not next_price.empty:
            df.at[index, "Price"] = (previous_price.iloc[0] + next_price.iloc[0]) / 2  # Promedio
        elif not previous_price.empty:
            df.at[index, "Price"] = previous_price.iloc[0]  # Usar solo el mes anterior
        elif not next_price.empty:
            df.at[index, "Price"] = next_price.iloc[0]  # Usar solo el mes siguiente
    
    return df

# Aplicar la función para rellenar valores faltantes
final_df = fill_missing_with_adjacent(final_df)

# Verificar si aún hay valores faltantes
print(final_df[final_df["Price"].isna()])
# Out:
# Empty DataFrame
# Columns: [Date, Region, Product, Unit, Price]
# Index: []

# %%
# Convertir la columna "Date" a tipo datetime, forzando los errores a NaN
final_df["Date"] = pd.to_datetime(final_df["Date"], errors="coerce")

# Mostrar las filas con valores faltantes
missing_values = final_df[final_df["Date"].isna()]
print(missing_values)
# Valores Correctos.
# Out:
# Empty DataFrame
# Columns: [Date, Region, Product, Unit, Price]
# Index: []

# %% [markdown]
# ### Verificar Outliers

# %%
# Obtener los 5 valores más bajos en "Price"
lowest_prices = final_df.nsmallest(5, "Price")
print("5 valores más bajos en Price:")
print(lowest_prices)

# Obtener los 5 valores más altos en "Price"
highest_prices = final_df.nlargest(5, "Price")
print("\n5 valores más altos en Price:")
print(highest_prices)
# Out:
# 5 valores más bajos en Price:
#            Date Region                Product Unit  Price
# 5131 2017-07-01   Cuyo  Harina de trigo común   kg  10.28
# 5130 2017-06-01   Cuyo  Harina de trigo común   kg  10.45
# 5132 2017-08-01   Cuyo  Harina de trigo común   kg  10.46
# 5133 2017-09-01   Cuyo  Harina de trigo común   kg  10.49
# 5135 2017-11-01   Cuyo  Harina de trigo común   kg  10.51
#
# 5 valores más altos en Price:
#            Date     Region             Product Unit    Price
# 6749 2024-11-01  Patagonia  Carne picada común   kg  6429.10
# 6748 2024-10-01  Patagonia  Carne picada común   kg  6106.38
# 6747 2024-09-01  Patagonia  Carne picada común   kg  6018.02
# 6741 2024-03-01  Patagonia  Carne picada común   kg  5797.99
# 6746 2024-08-01  Patagonia  Carne picada común   kg  5732.88

# %%
# Crear un identificador único incremental para cada fila, como entidad
final_df['product_id'] = range(1, len(final_df) + 1)
final_df
# Out:
#            Date     Region                    Product      Unit    Price  \
# 0    2017-06-01        GBA                Pan francés        kg    38.64
# 4860 2017-06-01   Noroeste                  Lavandina  1.000 cc    14.75
# 4770 2017-06-01   Noroeste         Detergente líquido    750 cc    23.05
# 4680 2017-06-01   Noroeste                     Azúcar        kg    16.35
# 4590 2017-06-01   Noroeste                       Papa        kg    11.33
# ...         ...        ...                        ...       ...      ...
# 5219 2024-11-01       Cuyo      Harina de trigo común        kg   839.74
# 5309 2024-11-01       Cuyo        Arroz blanco simple        kg  2267.79
# 5399 2024-11-01       Cuyo  Fideos secos tipo guisero     500 g  1312.29
# 5579 2024-11-01       Cuyo               Pollo entero        kg  3252.43
# 7559 2024-11-01  Patagonia           Jabón de tocador     125 g  1011.40
#
#       product_id
# 0              1
# 4860           2
# 4770           3
# 4680           4
# 4590           5
# ...          ...
# 5219        7556
# 5309        7557
# 5399        7558
# 5579        7559
# 7559        7560
#
# [7560 rows x 6 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7560 entries, 0 to 7559
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        7560 non-null   datetime64[ns]
#  1   Region      7560 non-null   object
#  2   Product     7560 non-null   object
#  3   Unit        7560 non-null   object
#  4   Price       7560 non-null   float64
#  5   product_id  7560 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 671.5+ KB

# %% [markdown]
# ### Los valores parecieran ser normales y siguen la tendencia de precios.

# %% [markdown]
# Create and Load at Alphacast

# %%
from alphacast import Alphacast
alphacast = Alphacast('ak_EZGOL3ajzMuwiwBV3fTT')

# %%
repo_name = "reto-tecnico" 
repo_description = "Prueba tecnica IPC completada"  
repo_slug = "reto-tecnico-mauricioarce" 
repo_privacy = "Public"  

# Crear el repositorio
repositorio = alphacast.repository.create(
    repo_name,
    repo_description=repo_description,
    slug=repo_slug,
    privacy=repo_privacy,
    returnIdIfExists=True 
)
print(f"Repositorio creado: {repositorio}")
# Out:
# Repositorio creado: {'id': 16342, 'name': 'reto-tecnico', 'description': 'Prueba tecnica IPC completada', 'privacy': 'Public', 'slug': 'reto-tecnico-16342'}

# %%
# Verificacion
alphacast.repository.read_by_id(16342)
# Out:
# {'id': 16342,
#  'name': 'reto-tecnico',
#  'accountId': 8751,
#  'description': 'Prueba tecnica IPC completada',
#  'privacy': 'Public',
#  'slug': 'reto-tecnico-16342',
#  'permission': 'Owner'}

# %%
# Crear dataset
dataset_name = 'prueba-tecnica-completada'
repo_id = 16342
description = 'Índice de precios al consumidor. Precios promedio de un conjunto de elementos de la canasta del IPC, según regiones (Junio de 2017-noviembre de 2024) y para el GBA (Abril de 2016-noviembre de 2024)'

alphacast.datasets.create(dataset_name, repo_id, description)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1420], line 6
#       3 repo_id = 16342
#       4 description = 'Índice de precios al consumidor. Precios promedio de un conjunto de elementos de la canasta del IPC, según regiones (Junio de 2017-noviembre de 2024) y para el GBA (Abril de 2016-noviembre de 2024)'
# ----> 6 alphacast.datasets.create(dataset_name, repo_id, description)
#
# File c:\Users\mauri\OneDrive\Escritorio\alphacast\_entornov\Lib\site-packages\alphacast\alphacast.py:76, in Datasets.create(self, dataset_name, repo_id, description, returnIdIfExists)
#      74         return previous_dataset
#      75     else:
# ---> 76         raise ValueError("Dataset already exists: {}".format(previous_dataset["id"]))
#      78 dataset = requests.post(url, data=form, auth=HTTPBasicAuth(self.api_key, ""))
#      79 return json.loads(dataset.content)
#
# ValueError: Dataset already exists: 43861

# %%
dataset_id = 43861
df = final_df[['Date', 'Region', 'Product', 'Unit', 'Price', 'product_id']]

# Inicializar columnas en Alphacast
alphacast.datasets.dataset(dataset_id).initialize_columns(
    dateColumnName="Date", 
    entitiesColumnNames=["product_id"], 
    dateFormat="%Y-%m-%d"
)
# Out:
# b'{"id": 43861, "columnDefinitions": [{"sourceName": "Date", "dataType": "Date", "dateFormat": "%Y-%m-%d", "isEntity": "True"}, {"sourceName": "product_id", "isEntity": "True"}], "updateAt": "2025-01-10T05:47:31.934318"}'

# %%
alphacast.datasets.dataset(43861).upload_data_from_df(df, deleteMissingFromDB = False, onConflictUpdateDB = False, uploadIndex=False)
# Out:
# b'{"id": 5148773, "status": "Requested", "createdAt": "2025-01-10T05:48:16.252345", "datasetId": 43861}'

# %%
alphacast.datasets.dataset(43861).processes()
# Out:
# b'[{"id": 5148773, "datasetId": 43861, "status": "Processed", "statusDescription": "7560 values added to database./n", "deleteMissingFromDB": 0, "onConflictUpdateDB": 0, "createdAt": "2025-01-10T05:48:16", "processedAt": "2025-01-10T05:48:19"}]'
